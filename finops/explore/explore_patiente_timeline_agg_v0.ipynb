# %%
#!/usr/bin/env python3
"""
Patient Timeline Creator
Creates a comprehensive timeline for patients by combining data from multiple tables.
"""

import pandas as pd
import duckdb as db
import os
from datetime import datetime
from typing import Dict, List, Tuple, Optional

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
def get_database_connection():
    """Create and return a connection to the huntington_data_lake database"""
    path_to_db = '../../database/huntington_data_lake.duckdb'
    conn = db.connect(path_to_db, read_only=True)
    
    print(f"Connected to database: {path_to_db}")
    print(f"Database file exists: {os.path.exists(path_to_db)}")
    
    return conn

def extract_timeline_data_for_patient(conn, test_prontuario):
    """Extract timeline data for a specific patient"""
    query = f"""
        SELECT * FROM gold.all_patients_timeline
        WHERE prontuario = {test_prontuario}
    """
    return conn.execute(query).fetchdf()

def explore_consultas(conn, test_prontuario):
    """Explore consultas for a specific patient"""
    query = f"""

        SELECT
            reference_value,
            COUNT(1) 
        FROM gold.recent_patients_timeline
        WHERE reference_value LIKE '%FIV%' OR reference_value LIKE '%FET%'
            -- AND prontuario = {test_prontuario}
        GROUP BY reference_value
        ORDER BY COUNT(1) DESC
    """
    return conn.execute(query).fetchdf()

# %%
def main(test_prontuario):
    """Main function to create patient timeline"""
    
    # Test with a single patient first
    # test_prontuario = 175583
    
    print(f"Creating timeline for patient: {test_prontuario}")
    
    # Get database connection
    conn = get_database_connection()
    
    try:
        # Extract timeline data
        timeline_df = extract_timeline_data_for_patient(conn, test_prontuario)
       
        agg_consultas_df = explore_consultas(conn, test_prontuario)
        
        return timeline_df, agg_consultas_df
        
    finally:
        conn.close()

# %%
if __name__ == "__main__":
    patient_id = 876_950
    # patient_id = 825_890 # Claudia
    patient_id = 175_583 # Renata
    # patient_id = 220_783 # caso cabelud0: - 26 tentativas
    # patient_id = 182_925 # caso completo
    timeline_df, agg_consultas_df = main(patient_id)
# Out:
# Creating timeline for patient: 175583
# Connected to database: ../../database/huntington_data_lake.duckdb
# Database file exists: True

# %%
timeline_df
# Out:
#     prontuario  event_id event_date             reference  \
# 0     175583.0   1359557 2025-03-27  extrato_atendimentos
# 1     175583.0   1330568 2025-02-14  extrato_atendimentos
# 2     175583.0   1321302 2025-01-23  extrato_atendimentos
# 3     175583.0   1300888 2024-12-11  extrato_atendimentos
# 4     175583.0   1293473 2024-11-28  extrato_atendimentos
# 5     175583.0     30324 2024-11-14           tratamentos
# 6     175583.0   1288113 2024-11-14  extrato_atendimentos
# 7     175583.0   1287384 2024-11-14  extrato_atendimentos
# 8     175583.0   1286377 2024-11-11  extrato_atendimentos
# 9     175583.0   1286062 2024-11-09  extrato_atendimentos
# 10    175583.0   1283881 2024-11-08  extrato_atendimentos
# 11    175583.0   1282479 2024-11-06  extrato_atendimentos
# 12    175583.0   1280629 2024-11-04  extrato_atendimentos
# 13    175583.0     30106 2024-10-26           tratamentos
# 14    175583.0   1274194 2024-10-26  extrato_atendimentos
# 15    175583.0   1273602 2024-10-26  extrato_atendimentos
# 16    175583.0   1269088 2024-10-23  extrato_atendimentos
# 17    175583.0   1269082 2024-10-21  extrato_atendimentos
# 18    175583.0   1268236 2024-10-15  extrato_atendimentos
# 19    175583.0     29511 2024-10-03           tratamentos
# 20    175583.0   1250533 2024-09-18  extrato_atendimentos
# 21    175583.0     28940 2024-09-05           tratamentos
# 22    175583.0   1218859 2024-08-20  extrato_atendimentos
# 23    175583.0   1204960 2024-08-09  extrato_atendimentos
# 24    175583.0   1169995 2024-06-25  extrato_atendimentos
# 25    175583.0   1157081 2024-05-27  extrato_atendimentos
#
#                      reference_value tentativa  flag_date_estimated  \
# 0            Consulta DOE: Receptora      None                False
# 1                Consulta Psicologia      None                False
# 2            Consulta DOE: Receptora      None                False
# 3            Consulta DOE: Receptora      None                False
# 4   Consulta de Reavaliação de Ciclo      None                False
# 5                 Ciclo a Fresco FIV         4                False
# 6                Coleta Seminal: FIV      None                False
# 7           Aspiração Folicular: FIV      None                False
# 8                        5º US Ciclo      None                False
# 9                        4º US Ciclo      None                False
# 10                       3º US Ciclo      None                False
# 11                       2º US Ciclo      None                False
# 12                       1° US Ciclo      None                False
# 13                Ciclo a Fresco FIV         3                False
# 14               Coleta Seminal: FIV      None                False
# 15          Aspiração Folicular: FIV      None                False
# 16                       3º US Ciclo      None                False
# 17                       2º US Ciclo      None                False
# 18                       1° US Ciclo      None                False
# 19                Ciclo a Fresco FIV         2                 True
# 20                       1° US Ciclo      None                False
# 21                Ciclo a Fresco FIV         1                 True
# 22                       1° US Ciclo      None                False
# 23       Fragmentação de DNA seminal      None                False
# 24      Retorno de Reprodução Humana      None                False
# 25     Consulta de Reprodução Humana      None                False
#
#                                       additional_info
# 0                                                  {}
# 1                                                  {}
# 2                                                  {}
# 3                                                  {}
# 4                                                  {}
# 5   {"Unidade": "1", "ResultadoTratamento": "No tr...
# 6                                                  {}
# 7                                                  {}
# 8                                                  {}
# 9                                                  {}
# 10                                                 {}
# 11                                                 {}
# 12                                                 {}
# 13  {"Unidade": "1", "ResultadoTratamento": "No tr...
# 14                                                 {}
# 15                                                 {}
# 16                                                 {}
# 17                                                 {}
# 18                                                 {}
# 19        {"Unidade": "1", "ResultadoTratamento": ""}
# 20                                                 {}
# 21  {"Unidade": "1", "ResultadoTratamento": "No tr...
# 22                                                 {}
# 23                                                 {}
# 24                                                 {}
# 25                                                 {}

# %%
agg_consultas_df
# Out:
#                                       reference_value  count(1)
# 0                                  Ciclo a Fresco FIV      2816
# 1                            Aspiração Folicular: FIV      2619
# 2                                 Coleta Seminal: FIV      2048
# 3                                  FET: Ciclo Próprio       904
# 4                       Descongelamentos Seminal: FIV       267
# 5                              FET: Excedente Próprio       202
# 6                                FET: Ciclo Receptora        99
# 7                            FET: Excedente Receptora        56
# 8                                   FET: Embriodoação        12
# 9   US Monitorização da ovulação FIV/Preservação/I...         6
# 10  1ºUS monitorização da ovulação FIV/Preservação...         3
# 11                             US - FIV/FET/ ICSI ***         1
# 12                                1º US Ciclo FIV ***         1
# 13              FET (Transferência de Congelados) ***         1
