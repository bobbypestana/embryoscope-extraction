# %%
#!/usr/bin/env python3
"""
Patient Timeline Creator
Creates a comprehensive timeline for patients by combining data from multiple tables.
"""

import pandas as pd
import duckdb as db
import os
from datetime import datetime
from typing import Dict, List, Tuple, Optional

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
def get_database_connection():
    """Create and return a connection to the clinisys_all database"""
    path_to_db = '../../database/clinisys_all.duckdb'
    conn = db.connect(path_to_db, read_only=True)
    
    print(f"Connected to database: {path_to_db}")
    print(f"Database file exists: {os.path.exists(path_to_db)}")
    
    return conn

def extract_timeline_data_for_patient(conn, prontuario: int) -> Dict[str, pd.DataFrame]:
    """
    Extract timeline data for a specific patient from all relevant tables
    """
    
    print(f"\n{'='*80}")
    print(f"EXTRACTING TIMELINE DATA FOR PRONTUARIO: {prontuario}")
    print(f"{'='*80}")
    
    timeline_data = {}
    
    # 1. view_tratamentos: id, data_procedimento, tentativa
    print(f"\n1. EXTRACTING view_tratamentos")
    try:
        tratamentos_df = conn.execute(f"""
            SELECT id, prontuario, data_procedimento, tentativa, 
                   tipo_procedimento, usuario_responsavel, unidade, resultado_tratamento,
                   data_inicio_inducao, dia_transferencia
            FROM silver.view_tratamentos 
            WHERE prontuario = {prontuario}
            ORDER BY data_procedimento
        """).fetchdf()
        
        print(f"Found {len(tratamentos_df)} treatment records")
        if len(tratamentos_df) > 0:
            print("Sample data:")
            print(tratamentos_df.head())
        
        timeline_data['tratamentos'] = tratamentos_df
        
    except Exception as e:
        print(f"Error extracting tratamentos: {str(e)}")
        timeline_data['tratamentos'] = pd.DataFrame()
    
    # 2. view_extrato_atendimentos_central: agendamento_id, data, agenda, agenda_nome
    print(f"\n2. EXTRACTING view_extrato_atendimentos_central")
    try:
        extrato_df = conn.execute(f"""
            SELECT agendamento_id, prontuario, data, agenda, agenda_nome,
                   inicio, medico, centro_custos, chegou, confirmado, procedimento_nome
            FROM silver.view_extrato_atendimentos_central 
            WHERE prontuario = {prontuario}
            ORDER BY data, inicio
        """).fetchdf()
        
        print(f"Found {len(extrato_df)} appointment records")
        if len(extrato_df) > 0:
            print("Sample data:")
            print(extrato_df.head())
        
        # Remove duplicates based on relevant columns (excluding agendamento_id)
        extrato_df = extrato_df.drop_duplicates(
            subset=['prontuario', 'data', 'procedimento_nome', 'confirmado'], 
            keep='first'
        )
        
        print(f"After removing duplicates: {len(extrato_df)} appointment records")
        timeline_data['extrato_atendimentos'] = extrato_df
        
    except Exception as e:
        print(f"Error extracting extrato_atendimentos: {str(e)}")
        timeline_data['extrato_atendimentos'] = pd.DataFrame()
    
    # 3. view_congelamentos_embrioes: CodCongelamento, data, ciclo, NEmbrioes
    print(f"\n3. EXTRACTING view_congelamentos_embrioes")
    try:
        cong_emb_df = conn.execute(f"""
            SELECT id, CodCongelamento, prontuario, Data, Ciclo, NEmbrioes,
                   Unidade, responsavel_recebimento, responsavel_armazenamento
            FROM silver.view_congelamentos_embrioes 
            WHERE prontuario = {prontuario}
            ORDER BY Data
        """).fetchdf()
        
        print(f"Found {len(cong_emb_df)} embryo freezing records")
        if len(cong_emb_df) > 0:
            print("Sample data:")
            print(cong_emb_df.head())
        
        timeline_data['congelamentos_embrioes'] = cong_emb_df
        
    except Exception as e:
        print(f"Error extracting congelamentos_embrioes: {str(e)}")
        timeline_data['congelamentos_embrioes'] = pd.DataFrame()
    
    # 4. view_congelamentos_ovulos: CodCongelamento, data, ciclo, NOvulos
    print(f"\n4. EXTRACTING view_congelamentos_ovulos")
    try:
        cong_ov_df = conn.execute(f"""
            SELECT id, CodCongelamento, prontuario, Data, Ciclo, NOvulos,
                   Unidade, responsavel_recebimento, responsavel_armazenamento
            FROM silver.view_congelamentos_ovulos 
            WHERE prontuario = {prontuario}
            ORDER BY Data
        """).fetchdf()
        
        print(f"Found {len(cong_ov_df)} oocyte freezing records")
        if len(cong_ov_df) > 0:
            print("Sample data:")
            print(cong_ov_df.head())
        
        timeline_data['congelamentos_ovulos'] = cong_ov_df
        
    except Exception as e:
        print(f"Error extracting congelamentos_ovulos: {str(e)}")
        timeline_data['congelamentos_ovulos'] = pd.DataFrame()
    
    # 5. view_descongelamentos_embrioes: CodDescongelamento, DataDescongelamento, ciclo
    print(f"\n5. EXTRACTING view_descongelamentos_embrioes")
    try:
        descong_emb_df = conn.execute(f"""
            SELECT id, CodDescongelamento, prontuario, DataDescongelamento, Ciclo,
                   Unidade, DataCongelamento, Transferencia, DataTransferencia
            FROM silver.view_descongelamentos_embrioes 
            WHERE prontuario = {prontuario}
            ORDER BY DataDescongelamento
        """).fetchdf()
        
        print(f"Found {len(descong_emb_df)} embryo thawing records")
        if len(descong_emb_df) > 0:
            print("Sample data:")
            print(descong_emb_df.head())
        
        timeline_data['descongelamentos_embrioes'] = descong_emb_df
        
    except Exception as e:
        print(f"Error extracting descongelamentos_embrioes: {str(e)}")
        timeline_data['descongelamentos_embrioes'] = pd.DataFrame()
    
    # 6. view_descongelamentos_ovulos: CodDescongelamento, DataDescongelamento, ciclo
    print(f"\n6. EXTRACTING view_descongelamentos_ovulos")
    try:
        descong_ov_df = conn.execute(f"""
            SELECT id, CodDescongelamento, prontuario, DataDescongelamento, Ciclo,
                   Unidade, DataCongelamento
            FROM silver.view_descongelamentos_ovulos 
            WHERE prontuario = {prontuario}
            ORDER BY DataDescongelamento
        """).fetchdf()
        
        print(f"Found {len(descong_ov_df)} oocyte thawing records")
        if len(descong_ov_df) > 0:
            print("Sample data:")
            print(descong_ov_df.head())
        
        timeline_data['descongelamentos_ovulos'] = descong_ov_df
        
    except Exception as e:
        print(f"Error extracting descongelamentos_ovulos: {str(e)}")
        timeline_data['descongelamentos_ovulos'] = pd.DataFrame()
    
    return timeline_data

def create_unified_timeline(timeline_data: Dict[str, pd.DataFrame], prontuario: int) -> pd.DataFrame:
    """
    Create a unified timeline from all extracted data
    """
    
    print(f"\n{'='*80}")
    print(f"CREATING UNIFIED TIMELINE FOR PRONTUARIO: {prontuario}")
    print(f"{'='*80}")
    
    timeline_events = []
    
    # Process each table and create timeline events
    for table_name, df in timeline_data.items():
        if df.empty:
            continue
            
        print(f"\nProcessing {table_name}: {len(df)} records")
        
        # Remove 'view_' prefix for display
        display_name = table_name.replace('view_', '')
        
        for _, row in df.iterrows():
            event = {
                'prontuario': prontuario,
                'table_name': display_name,
                'event_id': row.get('id', row.get('agendamento_id', row.get('CodCongelamento', row.get('CodDescongelamento', 'N/A')))),
                'event_date': None,
                'reference_column': None,
                'reference_value': None,
                'flag_date_estimated': False,  # Default to False for all events
                'additional_info': {}
            }
            
            # Extract date and reference information based on table
            if table_name == 'tratamentos':
                 # Handle ALL treatments - use data_procedimento if available, otherwise use data_inicio_inducao + 14 days
                 if pd.notna(row.get('data_procedimento')):
                     # Use original data_procedimento
                     event['event_date'] = row.get('data_procedimento')
                     event['flag_date_estimated'] = False
                 elif pd.notna(row.get('data_inicio_inducao')):
                     # Use data_inicio_inducao + 14 days as fallback
                     try:
                         # Convert data_inicio_inducao from string to date if needed
                         if isinstance(row.get('data_inicio_inducao'), str):
                             # Handle different date formats
                             for fmt in ['%d/%m/%Y', '%Y-%m-%d', '%d-%m-%Y', '%Y/%m/%d']:
                                 try:
                                     inducao_date = pd.to_datetime(row.get('data_inicio_inducao'), format=fmt)
                                     break
                                 except:
                                     continue
                             else:
                                 # If no specific format works, try pandas automatic parsing
                                 inducao_date = pd.to_datetime(row.get('data_inicio_inducao'))
                         else:
                             inducao_date = row.get('data_inicio_inducao')
                         
                         # Add 14 days to get estimated procedure date
                         estimated_date = inducao_date + pd.Timedelta(days=14)
                         event['event_date'] = estimated_date
                         event['flag_date_estimated'] = True
                         print(f"Using estimated date for tentativa {row.get('tentativa')}: {inducao_date} + 14 days = {estimated_date}")
                     except Exception as e:
                         print(f"Error estimating date for tentativa {row.get('tentativa')}: {e}")
                         continue  # Skip this record if we can't estimate the date
                 else:
                     # No date available - skip this treatment
                     print(f"Skipping treatment tentativa {row.get('tentativa')} - no date available")
                     continue
                 
                 event['reference_column'] = 'tipo_procedimento'
                 event['reference_value'] = f"{row.get('tipo_procedimento')} | {row.get('tentativa')}"
                 event['additional_info'] = {
                     'unidade': row.get('unidade'),
                     'resultado_tratamento': row.get('resultado_tratamento'),
                     'dia_transferencia': row.get('dia_transferencia')
                 }
                
            elif table_name == 'extrato_atendimentos':
                # Skip entries where procedimento_nome is null or confirmado is not 1
                if pd.isna(row.get('procedimento_nome')) or row.get('procedimento_nome') is None:
                    continue
                if row.get('confirmado') != 1:
                    continue
                    
                event['event_date'] = row.get('data')
                event['reference_column'] = 'procedimento_nome'
                event['reference_value'] = row.get('procedimento_nome')
                event['additional_info'] = {}
                
            elif table_name == 'congelamentos_embrioes':
                event['event_date'] = row.get('Data')
                event['reference_column'] = 'ciclo'
                event['reference_value'] = row.get('Ciclo')
                event['additional_info'] = {
                    'NEmbrioes': row.get('NEmbrioes'),
                    'Unidade': row.get('Unidade'),
                    'responsavel_recebimento': row.get('responsavel_recebimento'),
                    'responsavel_armazenamento': row.get('responsavel_armazenamento')
                }
                
            elif table_name == 'congelamentos_ovulos':
                event['event_date'] = row.get('Data')
                event['reference_column'] = 'ciclo'
                event['reference_value'] = row.get('Ciclo')
                event['additional_info'] = {
                    'NOvulos': row.get('NOvulos'),
                    'Unidade': row.get('Unidade'),
                    'responsavel_recebimento': row.get('responsavel_recebimento'),
                    'responsavel_armazenamento': row.get('responsavel_armazenamento')
                }
                
            elif table_name == 'descongelamentos_embrioes':
                event['event_date'] = row.get('DataDescongelamento')
                event['reference_column'] = 'ciclo'
                event['reference_value'] = row.get('Ciclo')
                event['additional_info'] = {
                    'CodDescongelamento': row.get('CodDescongelamento'),
                    'Unidade': row.get('Unidade'),
                    'DataCongelamento': row.get('DataCongelamento'),
                    'Transferencia': row.get('Transferencia'),
                    'DataTransferencia': row.get('DataTransferencia')
                }
                
            elif table_name == 'descongelamentos_ovulos':
                event['event_date'] = row.get('DataDescongelamento')
                event['reference_column'] = 'ciclo'
                event['reference_value'] = row.get('Ciclo')
                event['additional_info'] = {
                    'CodDescongelamento': row.get('CodDescongelamento'),
                    'Unidade': row.get('Unidade'),
                    'DataCongelamento': row.get('DataCongelamento')
                }
            
            # Only add events with valid dates
            if pd.notna(event['event_date']) and event['event_date'] is not None:
                timeline_events.append(event)
    
    # Create DataFrame and sort by date, table hierarchy, and event_id
    if timeline_events:
        timeline_df = pd.DataFrame(timeline_events)
        
        # Define table hierarchy for sorting
        table_hierarchy = {
            'extrato_atendimentos': 1,
            'congelamentos_ovulos': 2,
            'descongelamentos_ovulos': 3,
            'congelamentos_embrioes': 4,
            'descongelamentos_embrioes': 5,
            'tratamentos': 6,
        }
        
        # Add table_order column for sorting
        timeline_df['table_order'] = timeline_df['table_name'].map(table_hierarchy)
        
        # Sort by date DESC, table hierarchy DESC, event_id DESC
        timeline_df = timeline_df.sort_values(
            ['event_date', 'table_order', 'event_id'], 
            ascending=[False, False, False]
        )
        
        # Remove the temporary table_order column
        timeline_df = timeline_df.drop('table_order', axis=1)
        
        print(f"\nCreated timeline with {len(timeline_df)} events")
        print(f"Date range: {timeline_df['event_date'].min()} to {timeline_df['event_date'].max()}")
        
        return timeline_df
    else:
        print("\nNo timeline events found")
        return pd.DataFrame()

# REMOVED: Complex insert_missing_treatments function
# Now all treatments are handled in create_unified_timeline function

def display_timeline(timeline_df: pd.DataFrame, prontuario: int):
    """Display the timeline in a readable format"""
    
    if timeline_df.empty:
        print(f"\nNo timeline data available for prontuario {prontuario}")
        return
    
    print(f"\n{'='*100}")
    print(f"PATIENT TIMELINE - PRONTUARIO: {prontuario}")
    print(f"{'='*100}")
    
    for _, event in timeline_df.iterrows():
        date_str = event['event_date'].strftime('%Y-%m-%d') if pd.notna(event['event_date']) else 'Unknown'
        
        # Show estimated flag if applicable
        estimated_flag = " (ESTIMATED)" if event.get('flag_date_estimated', False) else ""
        print(f"\n📅 {date_str}{estimated_flag} | {event['table_name'].upper()}")
        print(f"   ID: {event['event_id']}")
        
        if pd.notna(event['reference_column']) and pd.notna(event['reference_value']):
            print(f"   {event['reference_column'].title()}: {event['reference_value']}")
        
        # Display additional info
        for key, value in event['additional_info'].items():
            if pd.notna(value) and value is not None:
                print(f"   {key}: {value}")
    
    print(f"\n{'='*100}")
    print(f"Total events: {len(timeline_df)}")
    print(f"Tables represented: {timeline_df['table_name'].unique()}")

def save_timeline_to_database(timeline_df: pd.DataFrame, prontuario: int):
    """Save timeline data to huntington_data_lake database in gold schema"""
    
    if timeline_df.empty:
        print(f"\nNo timeline data to save for prontuario {prontuario}")
        return
    
    print(f"\n{'='*80}")
    print(f"SAVING TIMELINE TO DATABASE FOR PRONTUARIO: {prontuario}")
    print(f"{'='*80}")
    
    try:
        # Connect to huntington_data_lake database
        path_to_db = 'database/huntington_data_lake.duckdb'
        conn = db.connect(path_to_db)
        
        print(f"Connected to database: {path_to_db}")
        
        # Create gold schema if it doesn't exist
        conn.execute("CREATE SCHEMA IF NOT EXISTS gold")
        
        # Convert additional_info dict to JSON string for storage
        timeline_df_copy = timeline_df.copy()
        
        # Handle additional_info conversion more robustly
        def safe_convert_additional_info(info_dict):
            if not info_dict:
                return "{}"
            try:
                # Convert any problematic values to strings
                cleaned_dict = {}
                for key, value in info_dict.items():
                    if pd.isna(value):
                        cleaned_dict[key] = None
                    else:
                        cleaned_dict[key] = str(value)
                return str(cleaned_dict)
            except Exception:
                return "{}"
        
        timeline_df_copy['additional_info'] = timeline_df_copy['additional_info'].apply(safe_convert_additional_info)
        
        # Always drop and recreate the table to ensure correct schema
        conn.execute("DROP TABLE IF EXISTS gold.patients_timeline")
        print("Dropped existing table (if any)")
        
        # Create new table with current data
        conn.execute("""
            CREATE TABLE gold.patients_timeline AS 
            SELECT * FROM timeline_df_copy
        """)
        print(f"Created new table with data for patient {prontuario}")
        
        # Get row count
        count_result = conn.execute("SELECT COUNT(*) as row_count FROM gold.patients_timeline").fetchdf()
        row_count = count_result['row_count'].iloc[0]
        
        print(f"Successfully saved {len(timeline_df)} timeline events to gold.patients_timeline")
        print(f"Total events in table: {row_count}")
        
        # Show sample of saved data
        sample_data = conn.execute("SELECT * FROM gold.patients_timeline LIMIT 5").fetchdf()
        print(f"\nSample of saved data:")
        print(sample_data.to_string(index=False))
        
        conn.close()
        
    except Exception as e:
        print(f"Error saving timeline to database: {str(e)}")
        if 'conn' in locals():
            conn.close()

def main(test_prontuario):
    """Main function to create patient timeline"""
    
    # Test with a single patient first
    # test_prontuario = 175583
    
    print(f"Creating timeline for patient: {test_prontuario}")
    
    # Get database connection
    conn = get_database_connection()
    
    try:
        # Extract timeline data
        timeline_data = extract_timeline_data_for_patient(conn, test_prontuario)
        
        # Create unified timeline (now handles all treatments including those with estimated dates)
        timeline_df = create_unified_timeline(timeline_data, test_prontuario)
        
        # Display timeline
        display_timeline(timeline_df, test_prontuario)
        
        # Save timeline to database
        save_timeline_to_database(timeline_df, test_prontuario)
        
        return timeline_df
        
    finally:
        conn.close()

# %%
if __name__ == "__main__":
    patient_id = 876_950
    # patient_id = 825_890 # Claudia
    patient_id = 175_583 # Renata
    patient_id = 220_783 # caso cabelud0: - 26 tentativas
    # patient_id = 182_925 # caso completo
    timeline_df = main(patient_id)
# Out:
# Creating timeline for patient: 220783
# Connected to database: ../../database/clinisys_all.duckdb
# Database file exists: True
#
# ================================================================================
# EXTRACTING TIMELINE DATA FOR PRONTUARIO: 220783
# ================================================================================
#
# 1. EXTRACTING view_tratamentos
# Found 26 treatment records
# Sample data:
#       id  prontuario data_procedimento tentativa    tipo_procedimento  \
# 0   4361      220783        2022-05-05         3   Ciclo a Fresco FIV
# 1  14733      220783        2022-08-31         7  Ciclo de Congelados
# 2  15264      220783        2022-09-25         8   Ciclo a Fresco FIV
# 3  16220      220783        2022-11-08        10   Ciclo a Fresco FIV
# 4  16703      220783        2022-12-03        11   Ciclo a Fresco FIV
#
#   usuario_responsavel  unidade resultado_tratamento data_inicio_inducao  \
# 0                3692     <NA>                 None          2022-04-18
# 1                3730        1             Negativo          2022-08-16
# 2                3692     <NA>                 None          2022-09-13
# 3                4945        1                 None          2022-10-30
# 4                4945        1                 None          2022-11-23
#
#   dia_transferencia
# 0       No transfer
# 1                 5
# 2       No transfer
# 3       No transfer
# 4       No transfer
#
# 2. EXTRACTING view_extrato_atendimentos_central
# Found 313 appointment records
# Sample data:
#    agendamento_id  prontuario       data  agenda                 agenda_nome  \
# 0          842990    220783.0 2021-12-19     213  Tarefas FIV - VILA MARIANA
# 1          842991    220783.0 2021-12-20     213  Tarefas FIV - VILA MARIANA
# 2          842992    220783.0 2021-12-21     213  Tarefas FIV - VILA MARIANA
# 3          842993    220783.0 2021-12-24     213  Tarefas FIV - VILA MARIANA
# 4          842994    220783.0 2021-12-25     213  Tarefas FIV - VILA MARIANA
#
#                inicio  medico  centro_custos chegou  confirmado  \
# 0 1900-01-01 08:30:00    <NA>              0   None           0
# 1 1900-01-01 08:30:00    <NA>              0   None           0
# 2 1900-01-01 08:30:00    <NA>              0   None           0
# 3 1900-01-01 08:30:00    <NA>              0   None           0
# 4 1900-01-01 08:30:00    <NA>              0   None           0
#
#   procedimento_nome
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# After removing duplicates: 191 appointment records
#
# 3. EXTRACTING view_congelamentos_embrioes
# Found 10 embryo freezing records
# Sample data:
#       id CodCongelamento  prontuario       Data       Ciclo  NEmbrioes  \
# 0   2144          E17443      220783 2021-10-11  IB 2144/21          1
# 1   5886          E18117      220783 2022-05-10    IB395/22          1
# 2  15799          E18512      220783 2022-08-06   IB1023/22          1
# 3  16735          E18752      220783 2022-09-30   IB1413/22          1
# 4  19716          E19255      220783 2023-02-11    IB192/23          1
#
#    Unidade  responsavel_recebimento  responsavel_armazenamento
# 0        1                     <NA>                       <NA>
# 1        1                     <NA>                       <NA>
# 2        1                     <NA>                       <NA>
# 3        1                     <NA>                       <NA>
# 4        1                     <NA>                       <NA>
#
# 4. EXTRACTING view_congelamentos_ovulos
# Found 0 oocyte freezing records
#
# 5. EXTRACTING view_descongelamentos_embrioes
# Found 4 embryo thawing records
# Sample data:
#       id CodDescongelamento  prontuario DataDescongelamento      Ciclo  \
# 0   9334            1244/22      220783          2022-08-31   IB395/22
# 1  11160           IB532/23      220783          2023-03-29  IB1413/22
# 2  12290             952/23      220783          2023-08-07    1110/23
# 3  15273            1463/24      220783          2024-07-15   ED119/24
#
#    Unidade DataCongelamento  Transferencia DataTransferencia
# 0     <NA>       2022-05-10           <NA>        2022-08-31
# 1        1       2022-09-30           <NA>        2023-03-29
# 2        1       2023-06-23           <NA>        2023-08-07
# 3        1       2024-04-03           <NA>        2024-07-15
#
# 6. EXTRACTING view_descongelamentos_ovulos
# Found 0 oocyte thawing records
#
# ================================================================================
# CREATING UNIFIED TIMELINE FOR PRONTUARIO: 220783
# ================================================================================
#
# Processing tratamentos: 26 records
# Using estimated date for tentativa 1: 2021-09-21 00:00:00 + 14 days = 2021-10-05 00:00:00
# Using estimated date for tentativa 2: 2021-12-04 00:00:00 + 14 days = 2021-12-18 00:00:00
# Using estimated date for tentativa 4: 2022-05-08 00:00:00 + 14 days = 2022-05-22 00:00:00
# Using estimated date for tentativa 5: 2022-06-15 00:00:00 + 14 days = 2022-06-29 00:00:00
# Using estimated date for tentativa 6: 2022-07-20 00:00:00 + 14 days = 2022-08-03 00:00:00
# Using estimated date for tentativa 9: 2022-10-09 00:00:00 + 14 days = 2022-10-23 00:00:00
# Using estimated date for tentativa 12: 2023-01-09 00:00:00 + 14 days = 2023-01-23 00:00:00
# Using estimated date for tentativa 14: 2023-02-23 00:00:00 + 14 days = 2023-03-09 00:00:00
#
# Processing extrato_atendimentos: 191 records
#
# Processing congelamentos_embrioes: 10 records
#
# Processing descongelamentos_embrioes: 4 records
#
# Created timeline with 157 events
# Date range: 2021-10-05 00:00:00 to 2024-11-23 00:00:00
#
# ====================================================================================================
# PATIENT TIMELINE - PRONTUARIO: 220783
# ====================================================================================================
#
# 📅 2024-11-23 | CONGELAMENTOS_EMBRIOES
#    ID: 27348
#    Ciclo: ED393/24
#    NEmbrioes: 2
#    Unidade: 2
#
# 📅 2024-11-18 | TRATAMENTOS
#    ID: 30659
#    Tipo_Procedimento: Ciclo a Fresco FIV | 26
#    unidade: 1
#    resultado_tratamento: No transfer
#    dia_transferencia: No transfer
#
# 📅 2024-11-18 | EXTRATO_ATENDIMENTOS
#    ID: 1292079
#    Procedimento_Nome: Coleta Seminal: FIV
#
# 📅 2024-11-18 | EXTRATO_ATENDIMENTOS
#    ID: 1291790
#    Procedimento_Nome: Ciclo Receptora
#
# 📅 2024-08-26 | EXTRATO_ATENDIMENTOS
#    ID: 1218853
#    Procedimento_Nome: US - Obstétrico
#
# 📅 2024-08-26 | EXTRATO_ATENDIMENTOS
#    ID: 1218852
#    Procedimento_Nome: US - Outros
#
# 📅 2024-08-19 | EXTRATO_ATENDIMENTOS
#    ID: 1212047
#    Procedimento_Nome: US - Outros
#
# 📅 2024-08-12 | EXTRATO_ATENDIMENTOS
#    ID: 1206423
#    Procedimento_Nome: 1º US Obstétrico: Confirmação
#
# 📅 2024-08-03 | EXTRATO_ATENDIMENTOS
#    ID: 1199372
#    Procedimento_Nome: Acompanhamento Beta HCG
#
# 📅 2024-07-25 | EXTRATO_ATENDIMENTOS
#    ID: 1190936
#    Procedimento_Nome: Acompanhamento Beta HCG
#
# 📅 2024-07-15 | TRATAMENTOS
#    ID: 27905
#    Tipo_Procedimento: Ciclo de Congelados | 25
#    unidade: 1
#    resultado_tratamento: Gestação Clínica
#    dia_transferencia: 5
#
# 📅 2024-07-15 | DESCONGELAMENTOS_EMBRIOES
#    ID: 15273
#    Ciclo: ED119/24
#    CodDescongelamento: 1463/24
#    Unidade: 1
#    DataCongelamento: 2024-04-03 00:00:00
#    DataTransferencia: 2024-07-15 00:00:00
#
# 📅 2024-07-15 | EXTRATO_ATENDIMENTOS
#    ID: 1190598
#    Procedimento_Nome: FET: Ciclo Receptora
#
# 📅 2024-07-10 | EXTRATO_ATENDIMENTOS
#    ID: 1183401
#    Procedimento_Nome: 2º US Ciclo
#
# 📅 2024-07-02 | EXTRATO_ATENDIMENTOS
#    ID: 1182749
#    Procedimento_Nome: 1° US Ciclo
#
# 📅 2024-04-17 | EXTRATO_ATENDIMENTOS
#    ID: 1134634
#    Procedimento_Nome: 1° US Ciclo
#
# 📅 2024-04-03 | CONGELAMENTOS_EMBRIOES
#    ID: 25121
#    Ciclo: ED119/24
#    NEmbrioes: 3
#    Unidade: 1
#
# 📅 2024-03-28 | EXTRATO_ATENDIMENTOS
#    ID: 1121674
#    Procedimento_Nome: Congelamento Seminal: Ciclo
#
# 📅 2024-03-21 | EXTRATO_ATENDIMENTOS
#    ID: 1115217
#    Procedimento_Nome: Avaliação clínica (sem cobrança)
#
# 📅 2024-03-21 | EXTRATO_ATENDIMENTOS
#    ID: 1114340
#    Procedimento_Nome: Consulta DOE: Receptora
#
# 📅 2024-03-01 | EXTRATO_ATENDIMENTOS
#    ID: 1102791
#    Procedimento_Nome: US - Outros
#
# 📅 2024-02-29 | EXTRATO_ATENDIMENTOS
#    ID: 1100310
#    Procedimento_Nome: Consulta DOE: Receptora
#
# 📅 2024-02-26 | EXTRATO_ATENDIMENTOS
#    ID: 1093297
#    Procedimento_Nome: Consulta de Reavaliação de Ciclo
#
# 📅 2024-02-15 | EXTRATO_ATENDIMENTOS
#    ID: 1086482
#    Procedimento_Nome: Acompanhamento Beta HCG
#
# 📅 2024-02-07 | EXTRATO_ATENDIMENTOS
#    ID: 1087333
#    Procedimento_Nome: Acompanhamento Beta HCG
#
# 📅 2024-02-05 | EXTRATO_ATENDIMENTOS
#    ID: 1085964
#    Procedimento_Nome: Transferência de Embriões a fresco: Receptora
#
# 📅 2024-02-05 | EXTRATO_ATENDIMENTOS
#    ID: 1085963
#    Procedimento_Nome: Transferência de Embriões a fresco: Próprio
#
# 📅 2024-02-02 | TRATAMENTOS
#    ID: 24859
#    Tipo_Procedimento: Ciclo a Fresco FIV | 24
#    unidade: 1
#    resultado_tratamento: Negativo
#    dia_transferencia: 3
#
# 📅 2024-02-02 | EXTRATO_ATENDIMENTOS
#    ID: 1083212
#    Procedimento_Nome: Coleta de Óvulos com Anestesia ***
#
# 📅 2024-01-31 | EXTRATO_ATENDIMENTOS
#    ID: 1083430
#    Procedimento_Nome: US - Outros ***
#
# 📅 2024-01-29 | EXTRATO_ATENDIMENTOS
#    ID: 1079101
#    Procedimento_Nome: US - Outros ***
#
# 📅 2024-01-24 | EXTRATO_ATENDIMENTOS
#    ID: 1076953
#    Procedimento_Nome: US - Outros ***
#
# 📅 2023-12-20 | EXTRATO_ATENDIMENTOS
#    ID: 1064260
#    Procedimento_Nome: US - Outros ***
#
# 📅 2023-12-08 | TRATAMENTOS
#    ID: 24125
#    Tipo_Procedimento: Ciclo a Fresco FIV | 23
#    unidade: 1
#    resultado_tratamento: No transfer
#    dia_transferencia: No transfer
#
# 📅 2023-12-08 | EXTRATO_ATENDIMENTOS
#    ID: 1058512
#    Procedimento_Nome: US - Outros ***
#
# 📅 2023-12-08 | EXTRATO_ATENDIMENTOS
#    ID: 1057811
#    Procedimento_Nome: Coleta de Óvulos com Anestesia ***
#
# 📅 2023-12-07 | EXTRATO_ATENDIMENTOS
#    ID: 1057761
#    Procedimento_Nome: 4º US - Ciclo  ***
#
# 📅 2023-12-06 | EXTRATO_ATENDIMENTOS
#    ID: 1055493
#    Procedimento_Nome: 3º US - Ciclo  ***
#
# 📅 2023-12-04 | EXTRATO_ATENDIMENTOS
#    ID: 1052167
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2023-11-29 | EXTRATO_ATENDIMENTOS
#    ID: 1050571
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2023-11-18 | CONGELAMENTOS_EMBRIOES
#    ID: 23832
#    Ciclo: 3007/23
#    NEmbrioes: 1
#    Unidade: 1
#
# 📅 2023-11-12 | TRATAMENTOS
#    ID: 23625
#    Tipo_Procedimento: Ciclo a Fresco FIV | 22
#    unidade: 1
#    resultado_tratamento: No transfer
#    dia_transferencia: No transfer
#
# 📅 2023-11-12 | EXTRATO_ATENDIMENTOS
#    ID: 1038924
#    Procedimento_Nome: Coleta de Óvulos com Anestesia ***
#
# 📅 2023-11-10 | EXTRATO_ATENDIMENTOS
#    ID: 1037055
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2023-11-07 | EXTRATO_ATENDIMENTOS
#    ID: 1031516
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2023-09-24 | TRATAMENTOS
#    ID: 22659
#    Tipo_Procedimento: Ciclo a Fresco FIV | 21
#    unidade: 1
#    resultado_tratamento: No transfer
#    dia_transferencia: No transfer
#
# 📅 2023-09-24 | EXTRATO_ATENDIMENTOS
#    ID: 1005043
#    Procedimento_Nome: Coleta de Óvulos com Anestesia ***
#
# 📅 2023-09-22 | EXTRATO_ATENDIMENTOS
#    ID: 1001913
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2023-09-08 | EXTRATO_ATENDIMENTOS
#    ID: 994286
#    Procedimento_Nome: Exame Outros ***
#
# 📅 2023-09-08 | EXTRATO_ATENDIMENTOS
#    ID: 994284
#    Procedimento_Nome: Biópsia do Endométrio ***
#
# 📅 2023-09-03 | TRATAMENTOS
#    ID: 22100
#    Tipo_Procedimento: Ciclo a Fresco FIV | 20
#    unidade: 1
#    resultado_tratamento: No transfer
#    dia_transferencia: No transfer
#
# 📅 2023-09-03 | EXTRATO_ATENDIMENTOS
#    ID: 992446
#    Procedimento_Nome: Coleta de Óvulos com Anestesia ***
#
# 📅 2023-09-01 | EXTRATO_ATENDIMENTOS
#    ID: 991766
#    Procedimento_Nome: 4º US - Ciclo  ***
#
# 📅 2023-08-31 | EXTRATO_ATENDIMENTOS
#    ID: 991500
#    Procedimento_Nome: 3º US - Ciclo  ***
#
# 📅 2023-08-30 | EXTRATO_ATENDIMENTOS
#    ID: 989625
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2023-08-28 | EXTRATO_ATENDIMENTOS
#    ID: 988229
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2023-08-19 | EXTRATO_ATENDIMENTOS
#    ID: 974608
#    Procedimento_Nome: Exames Betinha ***
#
# 📅 2023-08-07 | TRATAMENTOS
#    ID: 21398
#    Tipo_Procedimento: Ciclo de Congelados | 19
#    unidade: 1
#    resultado_tratamento: Gestação Química Confirmada
#    dia_transferencia: 5
#
# 📅 2023-08-07 | DESCONGELAMENTOS_EMBRIOES
#    ID: 12290
#    Ciclo: 1110/23
#    CodDescongelamento: 952/23
#    Unidade: 1
#    DataCongelamento: 2023-06-23 00:00:00
#    DataTransferencia: 2023-08-07 00:00:00
#
# 📅 2023-08-07 | EXTRATO_ATENDIMENTOS
#    ID: 974022
#    Procedimento_Nome: Transferência de embriões ***
#
# 📅 2023-08-07 | EXTRATO_ATENDIMENTOS
#    ID: 974021
#    Procedimento_Nome: Transferência de Embrião Congelado ***
#
# 📅 2023-08-01 | EXTRATO_ATENDIMENTOS
#    ID: 971465
#    Procedimento_Nome: 3º US - Ciclo  ***
#
# 📅 2023-07-31 | EXTRATO_ATENDIMENTOS
#    ID: 968298
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2023-07-26 | EXTRATO_ATENDIMENTOS
#    ID: 966988
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2023-06-23 | CONGELAMENTOS_EMBRIOES
#    ID: 22299
#    Ciclo: 1110/23
#    NEmbrioes: 1
#    Unidade: 1
#
# 📅 2023-06-18 | TRATAMENTOS
#    ID: 20514
#    Tipo_Procedimento: Ciclo a Fresco FIV | 18
#    unidade: 1
#    resultado_tratamento: No transfer
#    dia_transferencia: No transfer
#
# 📅 2023-06-18 | EXTRATO_ATENDIMENTOS
#    ID: 944558
#    Procedimento_Nome: Coleta de Óvulos com Anestesia ***
#
# 📅 2023-06-15 | EXTRATO_ATENDIMENTOS
#    ID: 941487
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2023-06-12 | EXTRATO_ATENDIMENTOS
#    ID: 941022
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2023-05-31 | CONGELAMENTOS_EMBRIOES
#    ID: 22059
#    Ciclo: IB888/23
#    NEmbrioes: 1
#    Unidade: 1
#
# 📅 2023-05-25 | TRATAMENTOS
#    ID: 20107
#    Tipo_Procedimento: Ciclo a Fresco FIV | 17
#    unidade: 1
#    resultado_tratamento: No transfer
#    dia_transferencia: No transfer
#
# 📅 2023-05-25 | EXTRATO_ATENDIMENTOS
#    ID: 931576
#    Procedimento_Nome: US - Outros ***
#
# 📅 2023-05-25 | EXTRATO_ATENDIMENTOS
#    ID: 929867
#    Procedimento_Nome: Coleta de Óvulos com Anestesia ***
#
# 📅 2023-05-25 | EXTRATO_ATENDIMENTOS
#    ID: 929866
#    Procedimento_Nome: Coleta de ciclo espontâneo com anestesia ***
#
# 📅 2023-05-22 | EXTRATO_ATENDIMENTOS
#    ID: 924839
#    Procedimento_Nome: US - Outros ***
#
# 📅 2023-05-11 | EXTRATO_ATENDIMENTOS
#    ID: 915805
#    Procedimento_Nome: Exames Betinha ***
#
# 📅 2023-05-01 | EXTRATO_ATENDIMENTOS
#    ID: 915101
#    Procedimento_Nome: Transferência de embriões ***
#
# 📅 2023-04-26 | TRATAMENTOS
#    ID: 19402
#    Tipo_Procedimento: Ciclo a Fresco FIV | 16
#    unidade: 1
#    resultado_tratamento: Gestação Química Confirmada
#    dia_transferencia: 5
#
# 📅 2023-04-26 | EXTRATO_ATENDIMENTOS
#    ID: 911249
#    Procedimento_Nome: Coleta de Óvulos com Anestesia ***
#
# 📅 2023-04-24 | EXTRATO_ATENDIMENTOS
#    ID: 910294
#    Procedimento_Nome: 4º US - Ciclo  ***
#
# 📅 2023-04-22 | EXTRATO_ATENDIMENTOS
#    ID: 908206
#    Procedimento_Nome: 3º US - Ciclo  ***
#
# 📅 2023-04-20 | EXTRATO_ATENDIMENTOS
#    ID: 904249
#    Procedimento_Nome: Consulta por Telemedicina terceira Via ***
#
# 📅 2023-04-19 | EXTRATO_ATENDIMENTOS
#    ID: 906929
#    Procedimento_Nome: US - Ciclo ***
#
# 📅 2023-04-17 | EXTRATO_ATENDIMENTOS
#    ID: 904113
#    Procedimento_Nome: US - Ciclo ***
#
# 📅 2023-04-10 | EXTRATO_ATENDIMENTOS
#    ID: 900239
#    Procedimento_Nome: Exames Betinha ***
#
# 📅 2023-04-08 | EXTRATO_ATENDIMENTOS
#    ID: 892967
#    Procedimento_Nome: Exames Betinha ***
#
# 📅 2023-03-29 | TRATAMENTOS
#    ID: 18758
#    Tipo_Procedimento: Ciclo de Congelados | 15
#    unidade: 1
#    resultado_tratamento: Gestação Química Confirmada
#    dia_transferencia: 5
#
# 📅 2023-03-29 | DESCONGELAMENTOS_EMBRIOES
#    ID: 11160
#    Ciclo: IB1413/22
#    CodDescongelamento: IB532/23
#    Unidade: 1
#    DataCongelamento: 2022-09-30 00:00:00
#    DataTransferencia: 2023-03-29 00:00:00
#
# 📅 2023-03-29 | EXTRATO_ATENDIMENTOS
#    ID: 892542
#    Procedimento_Nome: Transferência de Embrião Congelado ***
#
# 📅 2023-03-22 | EXTRATO_ATENDIMENTOS
#    ID: 886975
#    Procedimento_Nome: US - Ciclo ***
#
# 📅 2023-03-17 | EXTRATO_ATENDIMENTOS
#    ID: 884110
#    Procedimento_Nome: US - Outros ***
#
# 📅 2023-03-09 (ESTIMATED) | TRATAMENTOS
#    ID: 18261
#    Tipo_Procedimento: Ciclo de Congelados | 14
#    unidade: 1
#    resultado_tratamento: No transfer
#
# 📅 2023-03-07 | EXTRATO_ATENDIMENTOS
#    ID: 874221
#    Procedimento_Nome: US - Outros ***
#
# 📅 2023-02-27 | EXTRATO_ATENDIMENTOS
#    ID: 870350
#    Procedimento_Nome: US - Ciclo ***
#
# 📅 2023-02-27 | EXTRATO_ATENDIMENTOS
#    ID: 854406
#    Procedimento_Nome: 6º US - Ciclo  ***
#
# 📅 2023-02-23 | EXTRATO_ATENDIMENTOS
#    ID: 869344
#    Procedimento_Nome: US - Ciclo ***
#
# 📅 2023-02-11 | CONGELAMENTOS_EMBRIOES
#    ID: 19716
#    Ciclo: IB192/23
#    NEmbrioes: 1
#    Unidade: 1
#
# 📅 2023-02-06 | TRATAMENTOS
#    ID: 17779
#    Tipo_Procedimento: Ciclo a Fresco FIV | 13
#    unidade: 1
#    resultado_tratamento: No transfer
#    dia_transferencia: No transfer
#
# 📅 2023-02-06 | EXTRATO_ATENDIMENTOS
#    ID: 859242
#    Procedimento_Nome: Coleta de Óvulos com Anestesia ***
#
# 📅 2023-02-03 | EXTRATO_ATENDIMENTOS
#    ID: 857151
#    Procedimento_Nome: 3º US - Ciclo  ***
#
# 📅 2023-02-01 | EXTRATO_ATENDIMENTOS
#    ID: 854408
#    Procedimento_Nome: 6º US - Ciclo  ***
#
# 📅 2023-01-26 | EXTRATO_ATENDIMENTOS
#    ID: 853243
#    Procedimento_Nome: 5º US - Ciclo  ***
#
# 📅 2023-01-23 (ESTIMATED) | TRATAMENTOS
#    ID: 17414
#    Tipo_Procedimento: Ciclo a Fresco FIV | 12
#    unidade: 1
#
# 📅 2023-01-19 | EXTRATO_ATENDIMENTOS
#    ID: 846966
#    Procedimento_Nome: 4º US - Ciclo  ***
#
# 📅 2023-01-16 | EXTRATO_ATENDIMENTOS
#    ID: 843638
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2023-01-10 | EXTRATO_ATENDIMENTOS
#    ID: 843054
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2022-12-06 | EXTRATO_ATENDIMENTOS
#    ID: 827607
#    Procedimento_Nome: Consulta de Reavaliação de Ciclo ***
#
# 📅 2022-12-03 | TRATAMENTOS
#    ID: 16703
#    Tipo_Procedimento: Ciclo a Fresco FIV | 11
#    unidade: 1
#    dia_transferencia: No transfer
#
# 📅 2022-12-03 | EXTRATO_ATENDIMENTOS
#    ID: 824918
#    Procedimento_Nome: Coleta de Óvulos com Anestesia ***
#
# 📅 2022-12-01 | EXTRATO_ATENDIMENTOS
#    ID: 824164
#    Procedimento_Nome: 4º US - Ciclo  ***
#
# 📅 2022-11-30 | EXTRATO_ATENDIMENTOS
#    ID: 822476
#    Procedimento_Nome: 4º US - Ciclo  ***
#
# 📅 2022-11-28 | EXTRATO_ATENDIMENTOS
#    ID: 819546
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2022-11-23 | EXTRATO_ATENDIMENTOS
#    ID: 819417
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2022-11-08 | TRATAMENTOS
#    ID: 16220
#    Tipo_Procedimento: Ciclo a Fresco FIV | 10
#    unidade: 1
#    dia_transferencia: No transfer
#
# 📅 2022-11-08 | EXTRATO_ATENDIMENTOS
#    ID: 809195
#    Procedimento_Nome: Coleta de Óvulos com Anestesia ***
#
# 📅 2022-11-07 | EXTRATO_ATENDIMENTOS
#    ID: 807512
#    Procedimento_Nome: 3º US - Ciclo  ***
#
# 📅 2022-11-04 | EXTRATO_ATENDIMENTOS
#    ID: 805985
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2022-11-01 | EXTRATO_ATENDIMENTOS
#    ID: 804252
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2022-10-23 (ESTIMATED) | TRATAMENTOS
#    ID: 15787
#    Tipo_Procedimento: Ciclo a Fresco FIV | 9
#    unidade: 1
#
# 📅 2022-10-19 | EXTRATO_ATENDIMENTOS
#    ID: 795400
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2022-10-17 | EXTRATO_ATENDIMENTOS
#    ID: 794573
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2022-10-11 | EXTRATO_ATENDIMENTOS
#    ID: 790818
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2022-09-30 | CONGELAMENTOS_EMBRIOES
#    ID: 16735
#    Ciclo: IB1413/22
#    NEmbrioes: 1
#    Unidade: 1
#
# 📅 2022-09-25 | TRATAMENTOS
#    ID: 15264
#    Tipo_Procedimento: Ciclo a Fresco FIV | 8
#    dia_transferencia: No transfer
#
# 📅 2022-09-25 | EXTRATO_ATENDIMENTOS
#    ID: 655742
#    Procedimento_Nome: COLETA ADICIONAL ***
#
# 📅 2022-09-23 | EXTRATO_ATENDIMENTOS
#    ID: 654576
#    Procedimento_Nome: 3º US - Ciclo  ***
#
# 📅 2022-09-21 | EXTRATO_ATENDIMENTOS
#    ID: 650731
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2022-09-14 | EXTRATO_ATENDIMENTOS
#    ID: 650175
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2022-09-12 | EXTRATO_ATENDIMENTOS
#    ID: 648535
#    Procedimento_Nome: Consulta de Reavaliação de Ciclo ***
#
# 📅 2022-09-09 | EXTRATO_ATENDIMENTOS
#    ID: 642755
#    Procedimento_Nome: Exames Betinha ***
#
# 📅 2022-09-05 | EXTRATO_ATENDIMENTOS
#    ID: 643739
#    Procedimento_Nome: Exames Betinha ***
#
# 📅 2022-08-31 | TRATAMENTOS
#    ID: 14733
#    Tipo_Procedimento: Ciclo de Congelados | 7
#    unidade: 1
#    resultado_tratamento: Negativo
#    dia_transferencia: 5
#
# 📅 2022-08-31 | DESCONGELAMENTOS_EMBRIOES
#    ID: 9334
#    Ciclo: IB395/22
#    CodDescongelamento: 1244/22
#    DataCongelamento: 2022-05-10 00:00:00
#    DataTransferencia: 2022-08-31 00:00:00
#
# 📅 2022-08-31 | EXTRATO_ATENDIMENTOS
#    ID: 642201
#    Procedimento_Nome: Transferência de Embrião Congelado ***
#
# 📅 2022-08-25 | EXTRATO_ATENDIMENTOS
#    ID: 637468
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2022-08-22 | EXTRATO_ATENDIMENTOS
#    ID: 634050
#    Procedimento_Nome: US - Ciclo ***
#
# 📅 2022-08-22 | EXTRATO_ATENDIMENTOS
#    ID: 634049
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2022-08-16 | EXTRATO_ATENDIMENTOS
#    ID: 633267
#    Procedimento_Nome: Consulta de Reavaliação de Ciclo ***
#
# 📅 2022-08-06 | CONGELAMENTOS_EMBRIOES
#    ID: 15799
#    Ciclo: IB1023/22
#    NEmbrioes: 1
#    Unidade: 1
#
# 📅 2022-08-03 (ESTIMATED) | TRATAMENTOS
#    ID: 14240
#    Tipo_Procedimento: Ciclo a Fresco FIV | 6
#    dia_transferencia: No transfer
#
# 📅 2022-08-01 | EXTRATO_ATENDIMENTOS
#    ID: 622936
#    Procedimento_Nome: Coleta de Óvulos com Anestesia ***
#
# 📅 2022-07-29 | EXTRATO_ATENDIMENTOS
#    ID: 622595
#    Procedimento_Nome: 4º US - Ciclo  ***
#
# 📅 2022-07-27 | EXTRATO_ATENDIMENTOS
#    ID: 621491
#    Procedimento_Nome: 3º US - Ciclo  ***
#
# 📅 2022-07-25 | EXTRATO_ATENDIMENTOS
#    ID: 618625
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2022-07-20 | EXTRATO_ATENDIMENTOS
#    ID: 617659
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2022-07-18 | EXTRATO_ATENDIMENTOS
#    ID: 611039
#    Procedimento_Nome: US - Ciclo ***
#
# 📅 2022-06-29 (ESTIMATED) | TRATAMENTOS
#    ID: 13678
#    Tipo_Procedimento: Ciclo a Fresco FIV | 5
#
# 📅 2022-06-27 | EXTRATO_ATENDIMENTOS
#    ID: 604323
#    Procedimento_Nome: 3º US - Ciclo  ***
#
# 📅 2022-06-22 | EXTRATO_ATENDIMENTOS
#    ID: 602595
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2022-06-20 | EXTRATO_ATENDIMENTOS
#    ID: 600203
#    Procedimento_Nome: 2º US - Ciclo  ***
#
# 📅 2022-06-14 | EXTRATO_ATENDIMENTOS
#    ID: 599018
#    Procedimento_Nome: 1º US de Ciclo ***
#
# 📅 2022-05-22 (ESTIMATED) | TRATAMENTOS
#    ID: 4596
#    Tipo_Procedimento: Ciclo a Fresco FIV | 4
#
# 📅 2022-05-10 | CONGELAMENTOS_EMBRIOES
#    ID: 5886
#    Ciclo: IB395/22
#    NEmbrioes: 1
#    Unidade: 1
#
# 📅 2022-05-05 | TRATAMENTOS
#    ID: 4361
#    Tipo_Procedimento: Ciclo a Fresco FIV | 3
#    dia_transferencia: No transfer
#
# 📅 2021-12-18 (ESTIMATED) | TRATAMENTOS
#    ID: 2892
#    Tipo_Procedimento: Ciclo a Fresco FIV | 2
#    dia_transferencia: No transfer
#
# 📅 2021-10-11 | CONGELAMENTOS_EMBRIOES
#    ID: 2144
#    Ciclo: IB 2144/21
#    NEmbrioes: 1
#    Unidade: 1
#
# 📅 2021-10-05 (ESTIMATED) | TRATAMENTOS
#    ID: 1639
#    Tipo_Procedimento: Ciclo a Fresco FIV | 1
#    dia_transferencia: No transfer
#
# ====================================================================================================
# Total events: 157
# Tables represented: ['congelamentos_embrioes' 'tratamentos' 'extrato_atendimentos'
#  'descongelamentos_embrioes']
#
# ================================================================================
# SAVING TIMELINE TO DATABASE FOR PRONTUARIO: 220783
# ================================================================================
# Error saving timeline to database: IO Error: Cannot open file "g:\my drive\projetos_individuais\huntington\finops\explore\database\huntington_data_lake.duckdb": The system cannot find the path specified.

# %%
timeline_df
# Out:
#      prontuario                 table_name  event_id event_date  \
# 152      220783     congelamentos_embrioes     27348 2024-11-23
# 17       220783                tratamentos     30659 2024-11-18
# 142      220783       extrato_atendimentos   1292079 2024-11-18
# 141      220783       extrato_atendimentos   1291790 2024-11-18
# 139      220783       extrato_atendimentos   1218853 2024-08-26
# 140      220783       extrato_atendimentos   1218852 2024-08-26
# 138      220783       extrato_atendimentos   1212047 2024-08-19
# 137      220783       extrato_atendimentos   1206423 2024-08-12
# 136      220783       extrato_atendimentos   1199372 2024-08-03
# 135      220783       extrato_atendimentos   1190936 2024-07-25
# 16       220783                tratamentos     27905 2024-07-15
# 156      220783  descongelamentos_embrioes     15273 2024-07-15
# 134      220783       extrato_atendimentos   1190598 2024-07-15
# 133      220783       extrato_atendimentos   1183401 2024-07-10
# 132      220783       extrato_atendimentos   1182749 2024-07-02
# 131      220783       extrato_atendimentos   1134634 2024-04-17
# 151      220783     congelamentos_embrioes     25121 2024-04-03
# 130      220783       extrato_atendimentos   1121674 2024-03-28
# 129      220783       extrato_atendimentos   1115217 2024-03-21
# 128      220783       extrato_atendimentos   1114340 2024-03-21
# 127      220783       extrato_atendimentos   1102791 2024-03-01
# 126      220783       extrato_atendimentos   1100310 2024-02-29
# 125      220783       extrato_atendimentos   1093297 2024-02-26
# 124      220783       extrato_atendimentos   1086482 2024-02-15
# 123      220783       extrato_atendimentos   1087333 2024-02-07
# 121      220783       extrato_atendimentos   1085964 2024-02-05
# 122      220783       extrato_atendimentos   1085963 2024-02-05
# 15       220783                tratamentos     24859 2024-02-02
# 120      220783       extrato_atendimentos   1083212 2024-02-02
# 119      220783       extrato_atendimentos   1083430 2024-01-31
# 118      220783       extrato_atendimentos   1079101 2024-01-29
# 117      220783       extrato_atendimentos   1076953 2024-01-24
# 116      220783       extrato_atendimentos   1064260 2023-12-20
# 14       220783                tratamentos     24125 2023-12-08
# 115      220783       extrato_atendimentos   1058512 2023-12-08
# 114      220783       extrato_atendimentos   1057811 2023-12-08
# 113      220783       extrato_atendimentos   1057761 2023-12-07
# 112      220783       extrato_atendimentos   1055493 2023-12-06
# 111      220783       extrato_atendimentos   1052167 2023-12-04
# 110      220783       extrato_atendimentos   1050571 2023-11-29
# 150      220783     congelamentos_embrioes     23832 2023-11-18
# 13       220783                tratamentos     23625 2023-11-12
# 109      220783       extrato_atendimentos   1038924 2023-11-12
# 108      220783       extrato_atendimentos   1037055 2023-11-10
# 107      220783       extrato_atendimentos   1031516 2023-11-07
# 12       220783                tratamentos     22659 2023-09-24
# 106      220783       extrato_atendimentos   1005043 2023-09-24
# 105      220783       extrato_atendimentos   1001913 2023-09-22
# 103      220783       extrato_atendimentos    994286 2023-09-08
# 104      220783       extrato_atendimentos    994284 2023-09-08
# 11       220783                tratamentos     22100 2023-09-03
# 102      220783       extrato_atendimentos    992446 2023-09-03
# 101      220783       extrato_atendimentos    991766 2023-09-01
# 100      220783       extrato_atendimentos    991500 2023-08-31
# 99       220783       extrato_atendimentos    989625 2023-08-30
# 98       220783       extrato_atendimentos    988229 2023-08-28
# 97       220783       extrato_atendimentos    974608 2023-08-19
# 10       220783                tratamentos     21398 2023-08-07
# 155      220783  descongelamentos_embrioes     12290 2023-08-07
# 95       220783       extrato_atendimentos    974022 2023-08-07
# 96       220783       extrato_atendimentos    974021 2023-08-07
# 94       220783       extrato_atendimentos    971465 2023-08-01
# 93       220783       extrato_atendimentos    968298 2023-07-31
# 92       220783       extrato_atendimentos    966988 2023-07-26
# 149      220783     congelamentos_embrioes     22299 2023-06-23
# 9        220783                tratamentos     20514 2023-06-18
# 91       220783       extrato_atendimentos    944558 2023-06-18
# 90       220783       extrato_atendimentos    941487 2023-06-15
# 89       220783       extrato_atendimentos    941022 2023-06-12
# 148      220783     congelamentos_embrioes     22059 2023-05-31
# 8        220783                tratamentos     20107 2023-05-25
# 86       220783       extrato_atendimentos    931576 2023-05-25
# 87       220783       extrato_atendimentos    929867 2023-05-25
# 88       220783       extrato_atendimentos    929866 2023-05-25
# 85       220783       extrato_atendimentos    924839 2023-05-22
# 84       220783       extrato_atendimentos    915805 2023-05-11
# 83       220783       extrato_atendimentos    915101 2023-05-01
# 7        220783                tratamentos     19402 2023-04-26
# 82       220783       extrato_atendimentos    911249 2023-04-26
# 81       220783       extrato_atendimentos    910294 2023-04-24
# 80       220783       extrato_atendimentos    908206 2023-04-22
# 79       220783       extrato_atendimentos    904249 2023-04-20
# 78       220783       extrato_atendimentos    906929 2023-04-19
# 77       220783       extrato_atendimentos    904113 2023-04-17
# 76       220783       extrato_atendimentos    900239 2023-04-10
# 75       220783       extrato_atendimentos    892967 2023-04-08
# 6        220783                tratamentos     18758 2023-03-29
# 154      220783  descongelamentos_embrioes     11160 2023-03-29
# 74       220783       extrato_atendimentos    892542 2023-03-29
# 73       220783       extrato_atendimentos    886975 2023-03-22
# 72       220783       extrato_atendimentos    884110 2023-03-17
# 25       220783                tratamentos     18261 2023-03-09
# 71       220783       extrato_atendimentos    874221 2023-03-07
# 70       220783       extrato_atendimentos    870350 2023-02-27
# 69       220783       extrato_atendimentos    854406 2023-02-27
# 68       220783       extrato_atendimentos    869344 2023-02-23
# 147      220783     congelamentos_embrioes     19716 2023-02-11
# 5        220783                tratamentos     17779 2023-02-06
# 67       220783       extrato_atendimentos    859242 2023-02-06
# 66       220783       extrato_atendimentos    857151 2023-02-03
# 65       220783       extrato_atendimentos    854408 2023-02-01
# 64       220783       extrato_atendimentos    853243 2023-01-26
# 24       220783                tratamentos     17414 2023-01-23
# 63       220783       extrato_atendimentos    846966 2023-01-19
# 62       220783       extrato_atendimentos    843638 2023-01-16
# 61       220783       extrato_atendimentos    843054 2023-01-10
# 60       220783       extrato_atendimentos    827607 2022-12-06
# 4        220783                tratamentos     16703 2022-12-03
# 59       220783       extrato_atendimentos    824918 2022-12-03
# 58       220783       extrato_atendimentos    824164 2022-12-01
# 57       220783       extrato_atendimentos    822476 2022-11-30
# 56       220783       extrato_atendimentos    819546 2022-11-28
# 55       220783       extrato_atendimentos    819417 2022-11-23
# 3        220783                tratamentos     16220 2022-11-08
# 54       220783       extrato_atendimentos    809195 2022-11-08
# 53       220783       extrato_atendimentos    807512 2022-11-07
# 52       220783       extrato_atendimentos    805985 2022-11-04
# 51       220783       extrato_atendimentos    804252 2022-11-01
# 23       220783                tratamentos     15787 2022-10-23
# 50       220783       extrato_atendimentos    795400 2022-10-19
# 49       220783       extrato_atendimentos    794573 2022-10-17
# 48       220783       extrato_atendimentos    790818 2022-10-11
# 146      220783     congelamentos_embrioes     16735 2022-09-30
# 2        220783                tratamentos     15264 2022-09-25
# 47       220783       extrato_atendimentos    655742 2022-09-25
# 46       220783       extrato_atendimentos    654576 2022-09-23
# 45       220783       extrato_atendimentos    650731 2022-09-21
# 44       220783       extrato_atendimentos    650175 2022-09-14
# 43       220783       extrato_atendimentos    648535 2022-09-12
# 42       220783       extrato_atendimentos    642755 2022-09-09
# 41       220783       extrato_atendimentos    643739 2022-09-05
# 1        220783                tratamentos     14733 2022-08-31
# 153      220783  descongelamentos_embrioes      9334 2022-08-31
# 40       220783       extrato_atendimentos    642201 2022-08-31
# 39       220783       extrato_atendimentos    637468 2022-08-25
# 38       220783       extrato_atendimentos    634050 2022-08-22
# 37       220783       extrato_atendimentos    634049 2022-08-22
# 36       220783       extrato_atendimentos    633267 2022-08-16
# 145      220783     congelamentos_embrioes     15799 2022-08-06
# 22       220783                tratamentos     14240 2022-08-03
# 35       220783       extrato_atendimentos    622936 2022-08-01
# 34       220783       extrato_atendimentos    622595 2022-07-29
# 33       220783       extrato_atendimentos    621491 2022-07-27
# 32       220783       extrato_atendimentos    618625 2022-07-25
# 31       220783       extrato_atendimentos    617659 2022-07-20
# 30       220783       extrato_atendimentos    611039 2022-07-18
# 21       220783                tratamentos     13678 2022-06-29
# 29       220783       extrato_atendimentos    604323 2022-06-27
# 28       220783       extrato_atendimentos    602595 2022-06-22
# 27       220783       extrato_atendimentos    600203 2022-06-20
# 26       220783       extrato_atendimentos    599018 2022-06-14
# 20       220783                tratamentos      4596 2022-05-22
# 144      220783     congelamentos_embrioes      5886 2022-05-10
# 0        220783                tratamentos      4361 2022-05-05
# 19       220783                tratamentos      2892 2021-12-18
# 143      220783     congelamentos_embrioes      2144 2021-10-11
# 18       220783                tratamentos      1639 2021-10-05
#
#       reference_column                                reference_value  \
# 152              ciclo                                       ED393/24
# 17   tipo_procedimento                        Ciclo a Fresco FIV | 26
# 142  procedimento_nome                            Coleta Seminal: FIV
# 141  procedimento_nome                                Ciclo Receptora
# 139  procedimento_nome                                US - Obstétrico
# 140  procedimento_nome                                    US - Outros
# 138  procedimento_nome                                    US - Outros
# 137  procedimento_nome                  1º US Obstétrico: Confirmação
# 136  procedimento_nome                        Acompanhamento Beta HCG
# 135  procedimento_nome                        Acompanhamento Beta HCG
# 16   tipo_procedimento                       Ciclo de Congelados | 25
# 156              ciclo                                       ED119/24
# 134  procedimento_nome                           FET: Ciclo Receptora
# 133  procedimento_nome                                    2º US Ciclo
# 132  procedimento_nome                                    1° US Ciclo
# 131  procedimento_nome                                    1° US Ciclo
# 151              ciclo                                       ED119/24
# 130  procedimento_nome                    Congelamento Seminal: Ciclo
# 129  procedimento_nome               Avaliação clínica (sem cobrança)
# 128  procedimento_nome                        Consulta DOE: Receptora
# 127  procedimento_nome                                    US - Outros
# 126  procedimento_nome                        Consulta DOE: Receptora
# 125  procedimento_nome               Consulta de Reavaliação de Ciclo
# 124  procedimento_nome                        Acompanhamento Beta HCG
# 123  procedimento_nome                        Acompanhamento Beta HCG
# 121  procedimento_nome  Transferência de Embriões a fresco: Receptora
# 122  procedimento_nome    Transferência de Embriões a fresco: Próprio
# 15   tipo_procedimento                        Ciclo a Fresco FIV | 24
# 120  procedimento_nome             Coleta de Óvulos com Anestesia ***
# 119  procedimento_nome                                US - Outros ***
# 118  procedimento_nome                                US - Outros ***
# 117  procedimento_nome                                US - Outros ***
# 116  procedimento_nome                                US - Outros ***
# 14   tipo_procedimento                        Ciclo a Fresco FIV | 23
# 115  procedimento_nome                                US - Outros ***
# 114  procedimento_nome             Coleta de Óvulos com Anestesia ***
# 113  procedimento_nome                             4º US - Ciclo  ***
# 112  procedimento_nome                             3º US - Ciclo  ***
# 111  procedimento_nome                             2º US - Ciclo  ***
# 110  procedimento_nome                             1º US de Ciclo ***
# 150              ciclo                                        3007/23
# 13   tipo_procedimento                        Ciclo a Fresco FIV | 22
# 109  procedimento_nome             Coleta de Óvulos com Anestesia ***
# 108  procedimento_nome                             2º US - Ciclo  ***
# 107  procedimento_nome                             1º US de Ciclo ***
# 12   tipo_procedimento                        Ciclo a Fresco FIV | 21
# 106  procedimento_nome             Coleta de Óvulos com Anestesia ***
# 105  procedimento_nome                             1º US de Ciclo ***
# 103  procedimento_nome                               Exame Outros ***
# 104  procedimento_nome                      Biópsia do Endométrio ***
# 11   tipo_procedimento                        Ciclo a Fresco FIV | 20
# 102  procedimento_nome             Coleta de Óvulos com Anestesia ***
# 101  procedimento_nome                             4º US - Ciclo  ***
# 100  procedimento_nome                             3º US - Ciclo  ***
# 99   procedimento_nome                             2º US - Ciclo  ***
# 98   procedimento_nome                             1º US de Ciclo ***
# 97   procedimento_nome                             Exames Betinha ***
# 10   tipo_procedimento                       Ciclo de Congelados | 19
# 155              ciclo                                        1110/23
# 95   procedimento_nome                  Transferência de embriões ***
# 96   procedimento_nome         Transferência de Embrião Congelado ***
# 94   procedimento_nome                             3º US - Ciclo  ***
# 93   procedimento_nome                             2º US - Ciclo  ***
# 92   procedimento_nome                             1º US de Ciclo ***
# 149              ciclo                                        1110/23
# 9    tipo_procedimento                        Ciclo a Fresco FIV | 18
# 91   procedimento_nome             Coleta de Óvulos com Anestesia ***
# 90   procedimento_nome                             2º US - Ciclo  ***
# 89   procedimento_nome                             1º US de Ciclo ***
# 148              ciclo                                       IB888/23
# 8    tipo_procedimento                        Ciclo a Fresco FIV | 17
# 86   procedimento_nome                                US - Outros ***
# 87   procedimento_nome             Coleta de Óvulos com Anestesia ***
# 88   procedimento_nome   Coleta de ciclo espontâneo com anestesia ***
# 85   procedimento_nome                                US - Outros ***
# 84   procedimento_nome                             Exames Betinha ***
# 83   procedimento_nome                  Transferência de embriões ***
# 7    tipo_procedimento                        Ciclo a Fresco FIV | 16
# 82   procedimento_nome             Coleta de Óvulos com Anestesia ***
# 81   procedimento_nome                             4º US - Ciclo  ***
# 80   procedimento_nome                             3º US - Ciclo  ***
# 79   procedimento_nome     Consulta por Telemedicina terceira Via ***
# 78   procedimento_nome                                 US - Ciclo ***
# 77   procedimento_nome                                 US - Ciclo ***
# 76   procedimento_nome                             Exames Betinha ***
# 75   procedimento_nome                             Exames Betinha ***
# 6    tipo_procedimento                       Ciclo de Congelados | 15
# 154              ciclo                                      IB1413/22
# 74   procedimento_nome         Transferência de Embrião Congelado ***
# 73   procedimento_nome                                 US - Ciclo ***
# 72   procedimento_nome                                US - Outros ***
# 25   tipo_procedimento                       Ciclo de Congelados | 14
# 71   procedimento_nome                                US - Outros ***
# 70   procedimento_nome                                 US - Ciclo ***
# 69   procedimento_nome                             6º US - Ciclo  ***
# 68   procedimento_nome                                 US - Ciclo ***
# 147              ciclo                                       IB192/23
# 5    tipo_procedimento                        Ciclo a Fresco FIV | 13
# 67   procedimento_nome             Coleta de Óvulos com Anestesia ***
# 66   procedimento_nome                             3º US - Ciclo  ***
# 65   procedimento_nome                             6º US - Ciclo  ***
# 64   procedimento_nome                             5º US - Ciclo  ***
# 24   tipo_procedimento                        Ciclo a Fresco FIV | 12
# 63   procedimento_nome                             4º US - Ciclo  ***
# 62   procedimento_nome                             2º US - Ciclo  ***
# 61   procedimento_nome                             1º US de Ciclo ***
# 60   procedimento_nome           Consulta de Reavaliação de Ciclo ***
# 4    tipo_procedimento                        Ciclo a Fresco FIV | 11
# 59   procedimento_nome             Coleta de Óvulos com Anestesia ***
# 58   procedimento_nome                             4º US - Ciclo  ***
# 57   procedimento_nome                             4º US - Ciclo  ***
# 56   procedimento_nome                             2º US - Ciclo  ***
# 55   procedimento_nome                             1º US de Ciclo ***
# 3    tipo_procedimento                        Ciclo a Fresco FIV | 10
# 54   procedimento_nome             Coleta de Óvulos com Anestesia ***
# 53   procedimento_nome                             3º US - Ciclo  ***
# 52   procedimento_nome                             2º US - Ciclo  ***
# 51   procedimento_nome                             1º US de Ciclo ***
# 23   tipo_procedimento                         Ciclo a Fresco FIV | 9
# 50   procedimento_nome                             2º US - Ciclo  ***
# 49   procedimento_nome                             2º US - Ciclo  ***
# 48   procedimento_nome                             1º US de Ciclo ***
# 146              ciclo                                      IB1413/22
# 2    tipo_procedimento                         Ciclo a Fresco FIV | 8
# 47   procedimento_nome                           COLETA ADICIONAL ***
# 46   procedimento_nome                             3º US - Ciclo  ***
# 45   procedimento_nome                             2º US - Ciclo  ***
# 44   procedimento_nome                             1º US de Ciclo ***
# 43   procedimento_nome           Consulta de Reavaliação de Ciclo ***
# 42   procedimento_nome                             Exames Betinha ***
# 41   procedimento_nome                             Exames Betinha ***
# 1    tipo_procedimento                        Ciclo de Congelados | 7
# 153              ciclo                                       IB395/22
# 40   procedimento_nome         Transferência de Embrião Congelado ***
# 39   procedimento_nome                             2º US - Ciclo  ***
# 38   procedimento_nome                                 US - Ciclo ***
# 37   procedimento_nome                             1º US de Ciclo ***
# 36   procedimento_nome           Consulta de Reavaliação de Ciclo ***
# 145              ciclo                                      IB1023/22
# 22   tipo_procedimento                         Ciclo a Fresco FIV | 6
# 35   procedimento_nome             Coleta de Óvulos com Anestesia ***
# 34   procedimento_nome                             4º US - Ciclo  ***
# 33   procedimento_nome                             3º US - Ciclo  ***
# 32   procedimento_nome                             2º US - Ciclo  ***
# 31   procedimento_nome                             2º US - Ciclo  ***
# 30   procedimento_nome                                 US - Ciclo ***
# 21   tipo_procedimento                         Ciclo a Fresco FIV | 5
# 29   procedimento_nome                             3º US - Ciclo  ***
# 28   procedimento_nome                             2º US - Ciclo  ***
# 27   procedimento_nome                             2º US - Ciclo  ***
# 26   procedimento_nome                             1º US de Ciclo ***
# 20   tipo_procedimento                         Ciclo a Fresco FIV | 4
# 144              ciclo                                       IB395/22
# 0    tipo_procedimento                         Ciclo a Fresco FIV | 3
# 19   tipo_procedimento                         Ciclo a Fresco FIV | 2
# 143              ciclo                                     IB 2144/21
# 18   tipo_procedimento                         Ciclo a Fresco FIV | 1
#
#      flag_date_estimated                                    additional_info
# 152                False  {'NEmbrioes': 2, 'Unidade': 2, 'responsavel_re...
# 17                 False  {'unidade': 1, 'resultado_tratamento': 'No tra...
# 142                False                                                 {}
# 141                False                                                 {}
# 139                False                                                 {}
# 140                False                                                 {}
# 138                False                                                 {}
# 137                False                                                 {}
# 136                False                                                 {}
# 135                False                                                 {}
# 16                 False  {'unidade': 1, 'resultado_tratamento': 'Gestaç...
# 156                False  {'CodDescongelamento': '1463/24', 'Unidade': 1...
# 134                False                                                 {}
# 133                False                                                 {}
# 132                False                                                 {}
# 131                False                                                 {}
# 151                False  {'NEmbrioes': 3, 'Unidade': 1, 'responsavel_re...
# 130                False                                                 {}
# 129                False                                                 {}
# 128                False                                                 {}
# 127                False                                                 {}
# 126                False                                                 {}
# 125                False                                                 {}
# 124                False                                                 {}
# 123                False                                                 {}
# 121                False                                                 {}
# 122                False                                                 {}
# 15                 False  {'unidade': 1, 'resultado_tratamento': 'Negati...
# 120                False                                                 {}
# 119                False                                                 {}
# 118                False                                                 {}
# 117                False                                                 {}
# 116                False                                                 {}
# 14                 False  {'unidade': 1, 'resultado_tratamento': 'No tra...
# 115                False                                                 {}
# 114                False                                                 {}
# 113                False                                                 {}
# 112                False                                                 {}
# 111                False                                                 {}
# 110                False                                                 {}
# 150                False  {'NEmbrioes': 1, 'Unidade': 1, 'responsavel_re...
# 13                 False  {'unidade': 1, 'resultado_tratamento': 'No tra...
# 109                False                                                 {}
# 108                False                                                 {}
# 107                False                                                 {}
# 12                 False  {'unidade': 1, 'resultado_tratamento': 'No tra...
# 106                False                                                 {}
# 105                False                                                 {}
# 103                False                                                 {}
# 104                False                                                 {}
# 11                 False  {'unidade': 1, 'resultado_tratamento': 'No tra...
# 102                False                                                 {}
# 101                False                                                 {}
# 100                False                                                 {}
# 99                 False                                                 {}
# 98                 False                                                 {}
# 97                 False                                                 {}
# 10                 False  {'unidade': 1, 'resultado_tratamento': 'Gestaç...
# 155                False  {'CodDescongelamento': '952/23', 'Unidade': 1,...
# 95                 False                                                 {}
# 96                 False                                                 {}
# 94                 False                                                 {}
# 93                 False                                                 {}
# 92                 False                                                 {}
# 149                False  {'NEmbrioes': 1, 'Unidade': 1, 'responsavel_re...
# 9                  False  {'unidade': 1, 'resultado_tratamento': 'No tra...
# 91                 False                                                 {}
# 90                 False                                                 {}
# 89                 False                                                 {}
# 148                False  {'NEmbrioes': 1, 'Unidade': 1, 'responsavel_re...
# 8                  False  {'unidade': 1, 'resultado_tratamento': 'No tra...
# 86                 False                                                 {}
# 87                 False                                                 {}
# 88                 False                                                 {}
# 85                 False                                                 {}
# 84                 False                                                 {}
# 83                 False                                                 {}
# 7                  False  {'unidade': 1, 'resultado_tratamento': 'Gestaç...
# 82                 False                                                 {}
# 81                 False                                                 {}
# 80                 False                                                 {}
# 79                 False                                                 {}
# 78                 False                                                 {}
# 77                 False                                                 {}
# 76                 False                                                 {}
# 75                 False                                                 {}
# 6                  False  {'unidade': 1, 'resultado_tratamento': 'Gestaç...
# 154                False  {'CodDescongelamento': 'IB532/23', 'Unidade': ...
# 74                 False                                                 {}
# 73                 False                                                 {}
# 72                 False                                                 {}
# 25                  True  {'unidade': 1, 'resultado_tratamento': 'No tra...
# 71                 False                                                 {}
# 70                 False                                                 {}
# 69                 False                                                 {}
# 68                 False                                                 {}
# 147                False  {'NEmbrioes': 1, 'Unidade': 1, 'responsavel_re...
# 5                  False  {'unidade': 1, 'resultado_tratamento': 'No tra...
# 67                 False                                                 {}
# 66                 False                                                 {}
# 65                 False                                                 {}
# 64                 False                                                 {}
# 24                  True  {'unidade': 1, 'resultado_tratamento': None, '...
# 63                 False                                                 {}
# 62                 False                                                 {}
# 61                 False                                                 {}
# 60                 False                                                 {}
# 4                  False  {'unidade': 1, 'resultado_tratamento': None, '...
# 59                 False                                                 {}
# 58                 False                                                 {}
# 57                 False                                                 {}
# 56                 False                                                 {}
# 55                 False                                                 {}
# 3                  False  {'unidade': 1, 'resultado_tratamento': None, '...
# 54                 False                                                 {}
# 53                 False                                                 {}
# 52                 False                                                 {}
# 51                 False                                                 {}
# 23                  True  {'unidade': 1, 'resultado_tratamento': None, '...
# 50                 False                                                 {}
# 49                 False                                                 {}
# 48                 False                                                 {}
# 146                False  {'NEmbrioes': 1, 'Unidade': 1, 'responsavel_re...
# 2                  False  {'unidade': <NA>, 'resultado_tratamento': None...
# 47                 False                                                 {}
# 46                 False                                                 {}
# 45                 False                                                 {}
# 44                 False                                                 {}
# 43                 False                                                 {}
# 42                 False                                                 {}
# 41                 False                                                 {}
# 1                  False  {'unidade': 1, 'resultado_tratamento': 'Negati...
# 153                False  {'CodDescongelamento': '1244/22', 'Unidade': <...
# 40                 False                                                 {}
# 39                 False                                                 {}
# 38                 False                                                 {}
# 37                 False                                                 {}
# 36                 False                                                 {}
# 145                False  {'NEmbrioes': 1, 'Unidade': 1, 'responsavel_re...
# 22                  True  {'unidade': <NA>, 'resultado_tratamento': None...
# 35                 False                                                 {}
# 34                 False                                                 {}
# 33                 False                                                 {}
# 32                 False                                                 {}
# 31                 False                                                 {}
# 30                 False                                                 {}
# 21                  True  {'unidade': <NA>, 'resultado_tratamento': None...
# 29                 False                                                 {}
# 28                 False                                                 {}
# 27                 False                                                 {}
# 26                 False                                                 {}
# 20                  True  {'unidade': <NA>, 'resultado_tratamento': None...
# 144                False  {'NEmbrioes': 1, 'Unidade': 1, 'responsavel_re...
# 0                  False  {'unidade': <NA>, 'resultado_tratamento': None...
# 19                  True  {'unidade': <NA>, 'resultado_tratamento': None...
# 143                False  {'NEmbrioes': 1, 'Unidade': 1, 'responsavel_re...
# 18                  True  {'unidade': <NA>, 'resultado_tratamento': None...

# %%
timeline_df.loc[0,'additional_info']
# Out:
# {'unidade': <NA>,
#  'resultado_tratamento': None,
#  'dia_transferencia': 'No transfer'}
