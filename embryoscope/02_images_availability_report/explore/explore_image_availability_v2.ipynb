# %% [markdown]
# # Embryo Image Availability Explorer v2
#
# This notebook provides a structured way to explore the embryo image availability data recovered from logs.
#
# **Pattern**: All queries are executed at the beginning and the connection is closed, allowing for offline analysis of the fetched DataFrames.

# %%
import duckdb
import pandas as pd
import os
from datetime import datetime

# Set pandas display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## 1. Define Query Functions

# %%
def get_connection():
    """Get connection to huntington_data_lake database"""
    db_path = os.path.join('..', '..', '..', 'database', 'huntington_data_lake.duckdb')
    return duckdb.connect(db_path, read_only=True)

def fetch_overall_summary(conn):
    """Get high-level summary of availability"""
    return conn.execute("""
        SELECT 
            api_response_code,
            error_message as status_description,
            COUNT(*) as total_embryos,
            ROUND(COUNT(*) * 100.0 / SUM(COUNT(*)) OVER(), 2) as percentage
        FROM silver.embryo_image_availability_latest
        GROUP BY 1, 2
        ORDER BY 3 DESC
    """).df()

def fetch_server_summary(conn):
    """Get summary statistics per huntington unit/server"""
    return conn.execute("""
        SELECT 
            patient_unit_huntington as server,
            COUNT(*) as total_embryos,
            COUNT(DISTINCT prontuario) as unique_patients,
            SUM(CASE WHEN image_available THEN 1 ELSE 0 END) as with_images,
            SUM(CASE WHEN NOT image_available THEN 1 ELSE 0 END) as without_images,
            ROUND(AVG(CASE WHEN image_available THEN 1.0 ELSE 0.0 END) * 100, 2) as pct_with_images,
            ROUND(AVG(image_runs_count), 2) as avg_image_runs
        FROM silver.embryo_image_availability_latest
        GROUP BY patient_unit_huntington
        ORDER BY patient_unit_huntington
    """).df()

def fetch_temporal_distribution(conn):
    """Evolution of image availability over time (last 12 months)"""
    return conn.execute("""
        SELECT 
            DATE_TRUNC('month', embryo_EmbryoDate) as month,
            COUNT(*) as total_embryos,
            SUM(CASE WHEN image_available THEN 1 ELSE 0 END) as with_images,
            ROUND(AVG(CASE WHEN image_available THEN 1.0 ELSE 0.0 END) * 100, 2) as pct_with_images
        FROM silver.embryo_image_availability_latest
        GROUP BY DATE_TRUNC('month', embryo_EmbryoDate)
        ORDER BY month DESC
        --LIMIT 12
    """).df()

def fetch_patient_data(conn,):
    """Fetch all embryos for a specific patient"""
    return conn.execute(f"""
        SELECT * FROM silver.embryo_image_availability_latest 
        ORDER BY checked_at DESC
    """).df()

# %% [markdown]
# ## 2. Execute Data Extraction
# This cell fetches all required data and closes the database connection.

# %%
conn = get_connection()

try:
    print(f"Fetching data at {datetime.now()}...")
    
    # Execute all main queries
    df_overall = fetch_overall_summary(conn)
    df_servers = fetch_server_summary(conn)
    df_temporal = fetch_temporal_distribution(conn)
    
    # Optional: Fetch specific patient for demonstration
    df_patient = fetch_patient_data(conn)
    
    print("Done! All data cached in memory.")

finally:
    conn.close()
    print("Database connection closed.")
# Out:
# Fetching data at 2026-01-30 13:50:13.834790...
# Done! All data cached in memory.
# Database connection closed.

# %% [markdown]
# ## 3. Patient Data Example
# Showing data for prontuario used in the extraction cell.

# %%
prontuario = 814052
df_demo_patient = df_patient[df_patient.prontuario==prontuario]

print(f"\n{'='*80}")
print(f"PATIENT DATA EXAMPLE (Found {len(df_demo_patient)} embryos)")
print(f"{'='*80}")
display(df_demo_patient)
# Out:
# ================================================================================
# PATIENT DATA EXAMPLE (Found 28 embryos)
# ================================================================================
#                      embryo_EmbryoID  prontuario  patient_PatientID  \
# 15697  PC1P7BHG_45373.6014631481              Ibirapuera
# 15699  PC1P7BHG_45373.6014631481              Ibirapuera
# 15700  PC1P7BHG_45373.6014631481              Ibirapuera
#
#       treatment_TreatmentName embryo_EmbryoDate  image_available  \
# 15670                2024-446        2024-03-22             True
# 15671                2024-446        2024-03-22             True
# 15672                2024-446        2024-03-22             True
# 15674                2024-446        2024-03-22            False
# 15675                2024-446        2024-03-22             True
# 15676                2024-446        2024-03-22             True
# 15677                2024-446        2024-03-22             True
# 15678                2024-446        2024-03-22             True
# 15679                2024-446        2024-03-22             True
# 15680                2024-446        2024-03-22             True
# 15681                2024-446        2024-03-22             True
# 15682                2024-446        2024-03-22             True
# 15683                2024-446        2024-03-22             True
# 15684                2024-446        2024-03-22             True
# 15685                2024-446        2024-03-22             True
# 15687                2024-446        2024-03-22             True
# 15688                2024-446        2024-03-22             True
# 15689                2024-446        2024-03-22             True
# 15690                2024-446        2024-03-22             True
# 15691                2024-446        2024-03-22             True
# 15692                2024-446        2024-03-22             True
# 15693                2024-446        2024-03-22             True
# 15694                2024-446        2024-03-22             True
# 15695                2024-446        2024-03-22             True
# 15696                2024-446        2024-03-22             True
# 15697                2024-446        2024-03-22             True
# 15699                2024-446        2024-03-22             True
# 15700                2024-446        2024-03-22             True
#
#        image_runs_count api_response_status  api_response_code  \
# 15670             801.0             success                200
# 15671             801.0             success                200
# 15672             801.0             success                200
# 15674               0.0     silent_response                204
# 15675             801.0             success                200
# 15676             801.0             success                200
# 15677             801.0             success                200
# 15678             801.0             success                200
# 15679             801.0             success                200
# 15680             801.0             success                200
# 15681             801.0             success                200
# 15682             801.0             success                200
# 15683             800.0             success                200
# 15684             800.0             success                200
# 15685             800.0             success                200
# 15687             800.0             success                200
# 15688             800.0             success                200
# 15689             800.0             success                200
# 15690             800.0             success                200
# 15691             800.0             success                200
# 15692             800.0             success                200
# 15693             800.0             success                200
# 15694             800.0             success                200
# 15695             800.0             success                200
# 15696             800.0             success                200
# 15697             800.0             success                200
# 15699             800.0             success                200
# 15700             800.0             success                200
#
#                           error_message               checked_at  \
# 15670                                OK  2026-01-27 20:56:06,008
# 15671                                OK  2026-01-27 20:56:05,854
# 15672                                OK  2026-01-27 20:56:05,757
# 15674  No images found (Empty response)  2026-01-27 20:56:05,498
# 15675                                OK  2026-01-27 20:56:05,497
# 15676                                OK  2026-01-27 20:56:05,401
# 15677                                OK  2026-01-27 20:56:05,281
# 15678                                OK  2026-01-27 20:56:05,176
# 15679                                OK  2026-01-27 20:56:05,112
# 15680                                OK  2026-01-27 20:56:04,947
# 15681                                OK  2026-01-27 20:56:04,847
# 15682                                OK  2026-01-27 20:56:04,764
# 15683                                OK  2026-01-27 20:56:04,610
# 15684                                OK  2026-01-27 20:56:04,527
# 15685                                OK  2026-01-27 20:56:04,376
# 15687                                OK  2026-01-27 20:56:04,322
# 15688                                OK  2026-01-27 20:56:04,199
# 15689                                OK  2026-01-27 20:56:04,060
# 15690                                OK  2026-01-27 20:56:03,971
# 15691                                OK  2026-01-27 20:56:03,857
# 15692                                OK  2026-01-27 20:56:03,743
# 15693                                OK  2026-01-27 20:56:03,624
# 15694                                OK  2026-01-27 20:56:03,533
# 15695                                OK  2026-01-27 20:56:03,419
# 15696                                OK  2026-01-27 20:56:03,323
# 15697                                OK  2026-01-27 20:56:03,186
# 15699                                OK  2026-01-27 20:56:03,082
# 15700                                OK  2026-01-27 20:56:02,993
#
#                  last_updated
# 15670 2026-01-30 13:48:38.886
# 15671 2026-01-30 13:48:38.886
# 15672 2026-01-30 13:48:38.886
# 15674 2026-01-30 13:48:38.886
# 15675 2026-01-30 13:48:38.886
# 15676 2026-01-30 13:48:38.886
# 15677 2026-01-30 13:48:38.886
# 15678 2026-01-30 13:48:38.886
# 15679 2026-01-30 13:48:38.886
# 15680 2026-01-30 13:48:38.886
# 15681 2026-01-30 13:48:38.886
# 15682 2026-01-30 13:48:38.886
# 15683 2026-01-30 13:48:38.886
# 15684 2026-01-30 13:48:38.886
# 15685 2026-01-30 13:48:38.886
# 15687 2026-01-30 13:48:38.886
# 15688 2026-01-30 13:48:38.886
# 15689 2026-01-30 13:48:38.886
# 15690 2026-01-30 13:48:38.886
# 15691 2026-01-30 13:48:38.886
# 15692 2026-01-30 13:48:38.886
# 15693 2026-01-30 13:48:38.886
# 15694 2026-01-30 13:48:38.886
# 15695 2026-01-30 13:48:38.886
# 15696 2026-01-30 13:48:38.886
# 15697 2026-01-30 13:48:38.886
# 15699 2026-01-30 13:48:38.886
# 15700 2026-01-30 13:48:38.886

# %% [markdown]
# ## 4. Overall Availability Summary

# %%
display(df_overall)
# Out:
#    api_response_code                   status_description  total_embryos  \
# 0                200                                   OK          89460
# 1                204     No images found (Empty response)          22599
# 2                500  Unexpected error during data access           3292
# 3                  0                          Not Checked             10
#
#    percentage
# 0       77.55
# 1       19.59
# 2        2.85
# 3        0.01

# %% [markdown]
# ## 5. Summary by Server

# %%
print("\n" + "=" * 80)
print("SUMMARY BY SERVER")
print("=" * 80)
display(df_servers)
# Out:
# ================================================================================
# SUMMARY BY SERVER
# ================================================================================
#            server  total_embryos  unique_patients  with_images  \
# 0  Belo Horizonte          18864             1842       6303.0
# 1        Brasilia          14613             1533       8926.0
# 2      Ibirapuera          52107             5094      44970.0
# 3    Vila Mariana          29777             2706      29261.0
#
#    without_images  pct_with_images  avg_image_runs
# 0         12561.0            33.41          271.81
# 1          5687.0            61.08          497.46
# 2          7137.0            86.30          690.20
# 3           516.0            98.27          758.70

# %% [markdown]
# ## 6. Temporal Distribution (Last 12 Months)

# %%
print("\n" + "=" * 80)
print("TEMPORAL DISTRIBUTION")
print("=" * 80)
display(df_temporal.head(16))
# Out:
# ================================================================================
# TEMPORAL DISTRIBUTION
# ================================================================================
#         month  total_embryos  with_images  pct_with_images
# 0  2026-01-01            151        149.0            98.68
# 1  2025-12-01            842        469.0            55.70
# 2  2025-11-01           1522        815.0            53.55
# 3  2025-10-01           1303        744.0            57.10
# 4  2025-09-01           1394        791.0            56.74
# 5  2025-08-01           1212        673.0            55.53
# 6  2025-07-01           1326        702.0            52.94
# 7  2025-06-01           1690        998.0            59.05
# 8  2025-05-01           1741       1001.0            57.50
# 9  2025-04-01           1971       1227.0            62.25
# 10 2025-03-01           1574        977.0            62.07
# 11 2025-02-01           1481       1078.0            72.79
# 12 2025-01-01           1226       1201.0            97.96
# 13 2024-12-01           1192       1176.0            98.66
# 14 2024-11-01           1523       1498.0            98.36
# 15 2024-10-01           1236       1224.0            99.03
