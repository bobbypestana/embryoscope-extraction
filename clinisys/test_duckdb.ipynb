# %%
import duckdb

con = duckdb.connect('../database/test_duckdb.db')

con.close()

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\FilipeFurlanBellotti\anaconda3\envs\try_request\python.exe

# %%
import duckdb
print(duckdb.__version__)
# Out:
# 1.3.2

# %%
import os
os.chdir("g:/My Drive/projetos_individuais/Huntington")
# !python clinisys/init_duckdb.py
# Out:
# 2025-07-18 11:20:12,715 INFO Starting DuckDB database creation script (Desktop test)
# 2025-07-18 11:20:12,718 DEBUG Ensuring database directory exists: C:\Users\FilipeFurlanBellotti\Desktop
# 2025-07-18 11:20:12,722 INFO Database directory ensured: C:\Users\FilipeFurlanBellotti\Desktop
# 2025-07-18 11:20:12,722 DEBUG Attempting to create DuckDB at: C:\Users\FilipeFurlanBellotti\Desktop\clinisys_all.duckdb
# 2025-07-18 11:20:12,746 INFO DuckDB database created or opened at: C:\Users\FilipeFurlanBellotti\Desktop\clinisys_all.duckdb
# 2025-07-18 11:20:12,748 INFO DuckDB connection closed
# 2025-07-18 11:20:12,748 INFO DuckDB database creation script finished successfully

# %%
import os

# Make sure you are in the project root directory
os.chdir("g:/My Drive/projetos_individuais/Huntington")

# Run the bronze loader script
# !python clinisys/bronze_loader.py
# Out:
# 2025-07-21 11:21:05,965 INFO Starting bronze loader
# 2025-07-21 11:21:05,968 INFO DuckDB path: G:\My Drive\projetos_individuais\Huntington\database\clinisys_all.duckdb
# 2025-07-21 11:21:05,968 DEBUG Bronze loader started in debug mode
# 2025-07-21 11:21:05,970 DEBUG Found 16 CSV files in g:\My Drive\projetos_individuais\Huntington\clinisys\data_output
# 2025-07-21 11:21:05,970 DEBUG Connecting to DuckDB at G:\My Drive\projetos_individuais\Huntington\database\clinisys_all.duckdb
# 2025-07-21 11:21:06,052 INFO Connected to DuckDB at G:\My Drive\projetos_individuais\Huntington\database\clinisys_all.duckdb (file will be created if it does not exist)
# 2025-07-21 11:21:06,053 DEBUG Connected to DuckDB at G:\My Drive\projetos_individuais\Huntington\database\clinisys_all.duckdb (connection object: <duckdb.duckdb.DuckDBPyConnection object at 0x000002570717EF70>)
# ...

# %%
# !pip list
# Out:
# Package             Version
# ------------------- -----------
# asttokens           3.0.0
# Bottleneck          1.4.2
# certifi             2025.4.26
# charset-normalizer  3.4.2
# colorama            0.4.6
# comm                0.2.2
# contourpy           1.3.0
# cycler              0.12.1
# debugpy             1.8.14
# decorator           5.2.1
# duckdb              1.3.2
# exceptiongroup      1.3.0
# executing           2.2.0
# fonttools           4.58.5
# idna                3.10
# importlib_metadata  8.7.0
# importlib_resources 6.5.2
# ipykernel           6.29.5
# ipython             8.18.1
# jedi                0.19.2
# jupyter_client      8.6.3
# jupyter_core        5.8.1
# kiwisolver          1.4.7
# matplotlib          3.9.4
# matplotlib-inline   0.1.7
# mkl_fft             1.3.11
# mkl_random          1.2.8
# mkl-service         2.4.0
# nest_asyncio        1.6.0
# numexpr             2.10.1
# numpy               2.0.1
# packaging           25.0
# pandas              2.2.3
# ...
