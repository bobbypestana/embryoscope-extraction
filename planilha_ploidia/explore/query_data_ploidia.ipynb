# %% [markdown]
# # Data Ploidia Query
#
# This notebook queries the `gold.data_ploidia` table to investigate the results of the column mapping and filtering.
#
# ## Table Queried:
# - **Huntington Data Lake** (huntington_data_lake.duckdb):
#   - gold.data_ploidia (mapped and filtered columns from gold.planilha_embryoscope_combined)

# %%
import duckdb
import pandas as pd
import os
from datetime import datetime

# Set pandas display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Database Connection

# %%
def get_huntington_connection():
    """Get connection to huntington_data_lake database"""
    huntington_db_path = os.path.join('..', '..', 'database', 'huntington_data_lake.duckdb')
    return duckdb.connect(huntington_db_path, read_only=True)

# %% [markdown]
# ## Query Functions

# %%
def query_data_ploidia_all(conn):
    """Query all data from gold.data_ploidia"""
    print(f"\n=== GOLD.DATA_PLOIDIA (ALL DATA) ===")
    query = """
    SELECT * FROM gold.data_ploidia
    ORDER BY "Patient ID", "Video ID"
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records in gold.data_ploidia")
    return df

def query_data_ploidia_by_patient(conn, patient_id):
    """Query gold.data_ploidia for a specific patient ID"""
    print(f"\n=== GOLD.DATA_PLOIDIA (PATIENT ID: {patient_id}) ===")
    query = f"""
    SELECT * FROM gold.data_ploidia 
    WHERE "Patient ID" = {patient_id}
    ORDER BY "Video ID"
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records for Patient ID {patient_id}")
    return df

def query_data_ploidia_by_embryo(conn, embryo_id):
    """Query gold.data_ploidia for a specific embryo ID"""
    print(f"\n=== GOLD.DATA_PLOIDIA (EMBRYO ID: {embryo_id}) ===")
    query = f"""
    SELECT * FROM gold.data_ploidia 
    WHERE "Embryo ID" = '{embryo_id}' OR "Video ID" = '{embryo_id}'
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records for Embryo ID {embryo_id}")
    return df

def query_data_ploidia_by_unidade(conn, unidade):
    """Query gold.data_ploidia for a specific unidade"""
    print(f"\n=== GOLD.DATA_PLOIDIA (UNIDADE: {unidade}) ===")
    query = f"""
    SELECT * FROM gold.data_ploidia 
    WHERE "Unidade" = '{unidade}'
    ORDER BY "Patient ID", "Video ID"
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records for Unidade {unidade}")
    return df

def get_table_info(conn):
    """Get basic statistics about the data_ploidia table"""
    print(f"\n=== TABLE INFORMATION ===")
    
    # Row count
    row_count = conn.execute("SELECT COUNT(*) FROM gold.data_ploidia").fetchone()[0]
    print(f"Total rows: {row_count:,}")
    
    # Column count and names
    col_info = conn.execute("DESCRIBE gold.data_ploidia").df()
    print(f"Total columns: {len(col_info)}")
    print(f"\nColumn names:")
    for i, col in enumerate(col_info['column_name'], 1):
        print(f"  {i:2d}. {col}")
    
    # Check for NULL values in each column
    print(f"\nNULL value counts:")
    for col in col_info['column_name']:
        null_count = conn.execute(f'SELECT COUNT(*) FROM gold.data_ploidia WHERE "{col}" IS NULL').fetchone()[0]
        null_pct = (null_count / row_count * 100) if row_count > 0 else 0
        print(f"  {col:35s}: {null_count:6,} ({null_pct:5.1f}%)")
    
    return col_info

# %% [markdown]
# ## Main Query Function

# %%
def query_data_ploidia(patient_id=None, embryo_id=None, unidade=None, show_all=False):
    """
    Query data_ploidia table with various filters.
    
    Args:
        patient_id (int, optional): Filter by Patient ID
        embryo_id (str, optional): Filter by Embryo ID or Video ID
        unidade (str, optional): Filter by Unidade
        show_all (bool): If True, return all data
        
    Returns:
        pandas.DataFrame: Query results
    """
    print(f"\n{'='*80}")
    print(f"QUERYING DATA_PLOIDIA TABLE")
    print(f"Query executed at: {datetime.now()}")
    if patient_id:
        print(f"Filter: Patient ID = {patient_id}")
    if embryo_id:
        print(f"Filter: Embryo ID = {embryo_id}")
    if unidade:
        print(f"Filter: Unidade = {unidade}")
    if show_all:
        print(f"Filter: All data")
    print(f"{'='*80}")
    
    # Connect to database
    conn = get_huntington_connection()
    
    try:
        if show_all:
            df = query_data_ploidia_all(conn)
        elif patient_id:
            df = query_data_ploidia_by_patient(conn, patient_id)
        elif embryo_id:
            df = query_data_ploidia_by_embryo(conn, embryo_id)
        elif unidade:
            df = query_data_ploidia_by_unidade(conn, unidade)
        else:
            # Default: show first 100 rows
            print(f"\n=== GOLD.DATA_PLOIDIA (FIRST 100 ROWS) ===")
            query = """
            SELECT * FROM gold.data_ploidia
            ORDER BY "Patient ID", "Video ID"
            LIMIT 100
            """
            df = conn.execute(query).df()
            print(f"Showing first 100 records")
        
        return df
        
    finally:
        # Close connection
        conn.close()
        print("\nDatabase connection closed.")

# %% [markdown]
# ## Table Information

# %%
# Get table information
conn = get_huntington_connection()
try:
    col_info = get_table_info(conn)
finally:
    conn.close()
# Out:
# === TABLE INFORMATION ===
# Total rows: 16,969
# Total columns: 39
#
# Column names:
#    1. Unidade
#    2. Video ID
#    3. Age
#    4. BMI
#    5. Birth Year
#    6. Diagnosis
#    7. Patient Comments
#    8. Patient ID
#    9. Previus ET
#   10. Previus OD ET
#   11. Oocyte History
#   12. Oocyte Source
#   13. Oocytes Aspirated
#   14. Slide ID
#   15. Well
#   16. Embryo ID
#   17. t2
#   18. t3
#   19. t4
#   20. t5
#   21. t8
#   22. tB
#   23. tEB
#   24. tHB
#   25. tM
#   26. tPNa
#   27. tPNf
#   28. tSB
#   29. tSC
#   30. Frag-2 Cat. - Value
#   31. Fragmentation - Value
#   32. ICM - Value
#   33. MN-2 Type - Value
#   34. MN-2 Cells - Value
#   35. PN - Value
#   36. Pulsing - Value
#   37. Re-exp Count - Value
#   38. TE - Value
#   39. Embryo Description
#
# NULL value counts:
#   Unidade                            :      0 (  0.0%)
#   Video ID                           : 16,969 (100.0%)
#   Age                                :    211 (  1.2%)
#   BMI                                : 13,570 ( 80.0%)
#   Birth Year                         :    211 (  1.2%)
#   Diagnosis                          : 12,611 ( 74.3%)
#   Patient Comments                   : 16,969 (100.0%)
#   Patient ID                         :  5,907 ( 34.8%)
#   Previus ET                         :      0 (  0.0%)
#   Previus OD ET                      : 16,969 (100.0%)
#   Oocyte History                     :  5,923 ( 34.9%)
#   Oocyte Source                      : 13,386 ( 78.9%)
#   Oocytes Aspirated                  :  6,448 ( 38.0%)
#   Slide ID                           :      0 (  0.0%)
#   Well                               :      0 (  0.0%)
#   Embryo ID                          :      0 (  0.0%)
#   t2                                 :    928 (  5.5%)
#   t3                                 :  1,239 (  7.3%)
#   t4                                 :    997 (  5.9%)
#   t5                                 :  1,167 (  6.9%)
#   t8                                 :  1,239 (  7.3%)
#   tB                                 :  1,657 (  9.8%)
#   tEB                                :  9,538 ( 56.2%)
#   tHB                                : 10,787 ( 63.6%)
#   tM                                 : 10,804 ( 63.7%)
#   tPNa                               :  9,930 ( 58.5%)
#   tPNf                               :  1,005 (  5.9%)
#   tSB                                :  1,748 ( 10.3%)
#   tSC                                : 10,772 ( 63.5%)
#   Frag-2 Cat. - Value                :  7,033 ( 41.4%)
#   Fragmentation - Value              : 16,969 (100.0%)
#   ICM - Value                        :  1,635 (  9.6%)
#   MN-2 Type - Value                  :  7,039 ( 41.5%)
#   MN-2 Cells - Value                 :  6,404 ( 37.7%)
#   PN - Value                         :    546 (  3.2%)
#   Pulsing - Value                    : 11,411 ( 67.2%)
#   Re-exp Count - Value               : 13,347 ( 78.7%)
#   TE - Value                         :  1,638 (  9.7%)
#   Embryo Description                 :      0 (  0.0%)

# %% [markdown]
# ## Example Queries
#
# ### 1. Show All Data (First 100 rows)

# %%
# Query first 100 rows
df_all = query_data_ploidia()
display(df_all.sort_values(by=['Patient ID', 'Slide ID', 'Diagnosis', 'Well']))
# Out:
# ================================================================================
# QUERYING DATA_PLOIDIA TABLE
# Query executed at: 2025-12-15 14:31:44.551398
# ================================================================================
#
# === GOLD.DATA_PLOIDIA (FIRST 100 ROWS) ===
# Showing first 100 records
#
# Database connection closed.
#          Unidade  Video ID    Age    BMI  Birth Year  \
# 0     Ibirapuera      <NA>  36.53    NaN        1986
# 1     Ibirapuera      <NA>  41.01    NaN        1982
# 8     Ibirapuera      <NA>  34.40  20.89        1987
# 6     Ibirapuera      <NA>  34.40  20.89        1987
# 11    Ibirapuera      <NA>  34.40  20.89        1987
# 2     Ibirapuera      <NA>  34.40  20.89        1987
# 9     Ibirapuera      <NA>  34.40  20.89        1987
# 3     Ibirapuera      <NA>  34.40  20.89        1987
# 10  Vila Mariana      <NA>  37.11  20.89        1987
# 5   Vila Mariana      <NA>  37.11  20.89        1987
# 4   Vila Mariana      <NA>  37.11  20.89        1987
# 7   Vila Mariana      <NA>  37.11  20.89        1987
# 17    Ibirapuera      <NA>  37.93    NaN        1986
# 22    Ibirapuera      <NA>  37.93    NaN        1986
# 14    Ibirapuera      <NA>  37.93    NaN        1986
# 19    Ibirapuera      <NA>  37.93    NaN        1986
# 21    Ibirapuera      <NA>  37.93    NaN        1986
# 13    Ibirapuera      <NA>  37.93    NaN        1986
# 20    Ibirapuera      <NA>  37.93    NaN        1986
# 2            <NA>           Fresco      Homólogo                16
# 9            <NA>           Fresco      Homólogo                16
# 3            <NA>           Fresco      Homólogo                16
# 10           <NA>           Fresco      Homólogo                20
# 5            <NA>           Fresco      Homólogo                20
# 4            <NA>           Fresco      Homólogo                20
# 7            <NA>           Fresco      Homólogo                20
# 17           <NA>           Fresco          None                22
# 22           <NA>           Fresco          None                22
# 14           <NA>           Fresco          None                22
# 19           <NA>           Fresco          None                22
# 21           <NA>           Fresco          None                22
# 13           <NA>           Fresco          None                22
# 20           <NA>           Fresco          None                22
# 16           <NA>           Fresco      Homólogo                10
# 12           <NA>           Fresco      Homólogo                10
# 18           <NA>           Fresco      Homólogo                10
# 15           <NA>           Fresco      Homólogo                10
# 23           <NA>           Fresco      Homólogo                10
# 24           <NA>           Fresco          None                 8
# 27           <NA>  Descongelado OR    Heterólogo                12
# 28           <NA>  Descongelado OR    Heterólogo                12
# 25           <NA>  Descongelado OR    Heterólogo                12
# 29           <NA>  Descongelado OR    Heterólogo                12
# 26           <NA>  Descongelado OR    Heterólogo                12
# 35           <NA>           Fresco          None                 9
# 33           <NA>           Fresco          None                 9
# 32           <NA>           Fresco          None                 9
# 30           <NA>           Fresco          None                 9
# 31           <NA>           Fresco          None                 9
# 34           <NA>           Fresco          None                 9
# 36           <NA>           Fresco          None                 2
# 40           <NA>     Descongelado      Homólogo              None
# 42           <NA>     Descongelado      Homólogo              None
# 43           <NA>     Descongelado      Homólogo              None
# 41           <NA>     Descongelado      Homólogo              None
# 37           <NA>     Descongelado      Homólogo              None
# 38           <NA>     Descongelado      Homólogo              None
# 39           <NA>     Descongelado      Homólogo              None
# 46           <NA>  Descongelado OR          None              None
# 45           <NA>  Descongelado OR          None              None
# 47           <NA>  Descongelado OR          None              None
# 44           <NA>  Descongelado OR          None              None
# 48           <NA>  Descongelado OR          None              None
# 49           <NA>     Descongelado          None              None
# 51           <NA>     Descongelado          None                13
# 50           <NA>     Descongelado          None                13
# 52           <NA>     Descongelado          None                13
# 54           <NA>  Descongelado OR          None              None
# 53           <NA>  Descongelado OR          None              None
# 58           <NA>           Fresco          None                21
# 57           <NA>           Fresco          None                21
# 56           <NA>           Fresco          None                21
# 55           <NA>           Fresco          None                21
# 59           <NA>           Fresco          None                11
# 62           <NA>        Fresco OR    Heterólogo                13
# 60           <NA>        Fresco OR    Heterólogo                13
# 61           <NA>        Fresco OR    Heterólogo                13
# 64           <NA>        Fresco OR    Heterólogo                13
# 63           <NA>        Fresco OR    Heterólogo                13
# 66           <NA>           Fresco          None                 9
# 65           <NA>           Fresco      Homólogo                 6
# 68           <NA>  Descongelado OR          None                10
# 70           <NA>  Descongelado OR          None                10
# 67           <NA>  Descongelado OR          None                10
# 69           <NA>  Descongelado OR          None                10
# 73           <NA>     Descongelado          None                10
# 75           <NA>     Descongelado          None                10
# 74           <NA>     Descongelado          None                10
# 72           <NA>     Descongelado          None                10
# 71           <NA>     Descongelado          None                10
# 94  52.2   96.2  101.3  102.2   81.0   6.3  18.6   86.9  71.4
# 95  50.7  113.4    NaN    NaN   87.7   7.3  18.5  101.4  82.4
# 99  56.7  109.4  117.8  118.8   97.8   7.0  23.3  104.6  87.7
# 97  71.2  108.9  111.4  116.1   85.6   6.1  25.2   95.1  77.3
# 98  62.4  139.0    NaN    NaN   94.1   7.2  24.0  123.8  88.6
#
#     Frag-2 Cat. - Value  Fragmentation - Value ICM - Value MN-2 Type - Value  \
# 0                   NaN                    NaN           A              None
# 1                   NaN                    NaN           B              None
# 8                   NaN                    NaN           C              None
# 6                   NaN                    NaN           B              None
# 11                  NaN                    NaN           A              None
# 2                   NaN                    NaN           A              None
# 9                   NaN                    NaN           B              None
# 3                   NaN                    NaN           A              None
# 10                 25.1                    NaN           A                Bi
# 5                  28.4                    NaN           B              Mono
# 4                  43.9                    NaN           B                NA
# 7                  30.5                    NaN           B              Mono
# 17                 31.7                    NaN           C              Mono
# 22                 24.2                    NaN           A              Mono
# 14                 29.8                    NaN           B              Mono
# 19                 32.6                    NaN           B              Mono
# 21                 32.2                    NaN           B                Bi
# 13                 33.7                    NaN           A             Multi
# 20                 31.8                    NaN           C              Mono
# 16                 27.0                    NaN           A              Mono
# 12                 30.1                    NaN           A              Mono
# 18                 26.8                    NaN           A              Mono
# 15                 28.5                    NaN           A              Mono
# 23                 30.9                    NaN           B             Multi
# 24                 40.1                    NaN           C             Multi
# 27                 34.1                    NaN           A             Multi
# 28                 29.0                    NaN           A              Mono
# 25                 28.2                    NaN           B              Mono
# 29                 31.5                    NaN           A              Mono
# 26                 32.7                    NaN           A              Mono
# 35                  NaN                    NaN           A              None
# 33                  NaN                    NaN           A              None
# 32                  NaN                    NaN           B              None
# 30                  NaN                    NaN           B              None
# 31                  NaN                    NaN           A              None
# 34                  NaN                    NaN           A              None
# 36                  NaN                    NaN           A              None
# 40                 32.9                    NaN           A                Bi
# 42                 29.4                    NaN           B              Mono
# 43                 25.8                    NaN           B              Mono
# 41                 32.0                    NaN           C              Mono
# 37                 39.7                    NaN           B              Mono
# 38                 39.2                    NaN           B              Mono
# 39                 30.9                    NaN           B              Mono
# 46                 31.8                    NaN           B              Mono
# 45                 35.7                    NaN           B             Multi
# 47                 32.2                    NaN           A              Mono
# 44                 34.8                    NaN           B              Mono
# 48                 37.2                    NaN           A              Mono
# 49                  NaN                    NaN        None              None
# 51                  NaN                    NaN           A              None
# 50                  NaN                    NaN        None              None
# 52                  NaN                    NaN           B              None
# 54                  NaN                    NaN           A              None
# 53                  NaN                    NaN           B              None
# 58                  NaN                    NaN           A              None
# 57                  NaN                    NaN           A              None
# 56                  NaN                    NaN           A              None
# 55                  NaN                    NaN           A              None
# 59                 30.2                    NaN           B              Mono
# 62                 24.7                    NaN           B             Multi
# 60                 29.6                    NaN           A             Multi
# 61                 30.1                    NaN           B             Multi
# 64                 29.8                    NaN           A             Multi
# 63                 27.3                    NaN           A             Multi
# 55               None          2            None                 None
# 59                  0          2            None                 None
# 62                  2          2              No                 None
# 60                  2          2              No                 None
# 61                  1          2              No                 None
# 64                  1          2             Yes                 None
# 63                  2          2              No                 None
# 66                  2          2            None                 None
# 65               None          2            None                 None
# 68               None          2            None                 None
# 70               None          2            None                 None
# 67               None          2            None                 None
# 69               None          2            None                 None
# 73                  0          2            None                 None
# 75                  0          2            None                 None
# 74                  1          2            None                 None
# 72                  1          2            None                 None
# 71               None          2            None                 None
# 76                  0          2            None                 None
# 77                  0          2            None                 None
# 82                  0          2            None                 None
# 80                  0          4            None                 None
# 81                  1          2            None                 None
# 84                  0          2            None                 None
# 83                  0          2            None                 None
# 78                  1          3            None                 None
# 79                  0          2            None                 None
# 87                  1          2            None                 None
# 88                  0          2            None                 None
# 86               None          2            None                 None
# 89                  0          2            None                 None
# 85               None          2            None                 None
# 90               None          2            None                 None
# 91               None          2            None                 None
# 92               None          2            None                 None
# 96                  0          2            None                 None
# 93                  2          2            None                 None
# 94                  0          2            None                 None
# 95                  0          2            None                 None
# 99                  1          2            None                 None
# 97                  2          2            None                 None
# 98                  1          2            None                 None
#
#    TE - Value                                             Embryo Description
# 0           B                                        Complex Aneuploid +2,+9
# 1           B                                                    Euploid, XX
# 8           B                                                        Euploid
# 6           B                                    Complex Aneuploid +1,+5,-18
# 11          B                                                        Euploid
# 2           B                                                        Euploid
# 9           B                                                  Aneuploid +16
# 3           C                                                        Euploid
# 10          A                                                    EUPLOIDE XY
# 5           C          ANEUPLOIDE: TRISSOMIA CHR 8 EM MOSAICO BAIXO GRAU, XX
# 4           B                                            ANEUPLOIDE: +13, XY
# 7           B                                            ANEUPLOIDE: +5q, XX
# 17          C             Complex aneuploid /unbalanced monosomy  14,22, +21
# 22          B                                             Euploid/ balanced
# 14          B                                     Aneuploid / unbalanced +22
# 19          B                             Aneuploid / unbalanced  monossomy
# 21          B               Complex aneuploid /unbalanced  monossomy  21 +16
# 13          B                    Complex aneuploid /unbalanced monosomy  22
# 20          C           Complex aneuploid /unbalanced monosomy  14,16 and 22
# 16          B                                        Aneuploid +11q, -15, XY
# 12          A                                           Euploid balanced, XY
# 18          B                                   Aneuploid +11q, -12, -22, XX
# 15          A                                    Aneuploid -13, -16,+17p, XY
# 23          B                                               Aneuploid -1, XX
# 24          C                                     Complex Aneuploid -15,+19q
# 27          A                                                    Euploide XY
# 28          A                                              Aneuploide +9q XY
# 25          A                                                    Euploide XX
# 29          B                                                    Euploide XX
# 26          A                                                    Euploide XX
# 35          B                                             Euploide, Feminino
# 33          A                                            Euploide, Masculino
# 32          B                                             Euploide, Feminino
# 30          A                                            Euploide, Masculino
# 31          A                                             Euploide, Feminino
# 34          A                                             Euploide, Feminino
# 36          B                              Aneuploide Complexo: -7, +21, +22
# 40          B                                              Aneuploid +8p, XX
# 42          A                                                     Euploid XX
# 43          B                                             Aneuploid +17q, XY
# 41          C                                 Complex Aneuploid +21, +22, XX
# 37          B                                                     Euploid XX
# 38          B                                                     Euploid XX
# 39          B                                                     Euploid XX
# 46          B                                                     Euploid XY
# 45          C                                                     Euploid XX
# 47          B                                                     Euploid XY
# 44          A                                               Aneuploid -4, XY
# 48          B                                                     Euploid XY
# 49       None                                    Complex aneuplid +8,+13+,15
# 51          A                                                        Euploid
# 50       None                                                   Aneuploid -8
# 52          C                                                        Euploid
# 54          B                                                     EUPLOID XY
# 53          C                                                     EUPLOID XX
# 58          A                                                        Euploid
# 57          A                                                        Euploid
# 56          A                                                        Euploid
# 55          A                                                        Euploid
# 59          B                                  Complex Aneuploid +15,+20, XX
# 62          B                                                   EUPLOIDE XY
# 60          A                                                    EUPLOIDE XX
# 61          B                                                   EUPLOIDE XY
# 64          A                                                    EUPLOIDE XX
# 63          A                                                   EUPLOIDE XY
# 66          C                                 Complex Aneuploid +6,+13q,+14q
# 65          A                                                     Euploid XY
# 68          B                                  Complex Aneuploid -8, +18, XX
# 70          C                           High-level Aneuploid Mopsaic +1q, XX
# 67          B                                                    Euploid, XX
# 69          B                                                    Euploid, XY
# 73          C                                            EUPLOIDE (FEMININO)
# 75          C                                            EUPLOIDE (FEMININO)
# 74          B                                            EUPLOIDE (FEMININO)
# 72          C  ANEUPLOIDE COMPLEXO: -11, -12, +18P, +19, -21, -22 (FEMININO)
# 71          B                                     ANEUPLOIDE: +2P (FEMININO)
# 76          B                                                     Euploid XX
# 77          A                                                     Euploid XX
# 82          A                                                     Euploid XY
# 80          A                                                    sem analise
# 81          A                                              Aneuploid +16, XX
# 84          B                                                     Euploid XY
# 83          B                                Complex Aneuploid -15,+3,+9, XX
# 78          B                                                    sem analise
# 79          A                                              Aneuploid -21, XY
# 87          C                                        BIOPSIADO (SEM ANALISE)
# 88          C                                        BIOPSIADO (SEM ANALISE)
# 86          B                                                       EUPLOIDE
# 89          C                                        BIOPSIADO (SEM ANALISE)
# 85          A                                                       EUPLOIDE
# 90       None        Complex Aneuploid +1, +3p, +6, +7q, -10, -13q, +14, +20
# 91       None                                      Complex Aneuploid -7, +19
# 92          B                                                        Euploid
# 96          A                                                       EUPLOIDE
# 93          A                              ANEUPLOIDE COMPLEXO: +5, +15, +18
# 94          A                                                       EUPLOIDE
# 95          C                                 ANEUPLOIDE COMPLEXO: +3P, +10Q
# 99          A                                                   SEM BIOPSIA
# 97          A                                                   SEM BIOPSIA
# 98          B                                  ANEUPLOIDE COMPLEXO: -10, +20

# %%
patient_id = '138475'
display(df_all[df_all['Patient ID']==patient_id].sort_values(by=['Diagnosis', 'Well']))
# Out:
# Empty DataFrame
# Columns: [Unidade, Video ID, Age, BMI, Birth Year, Diagnosis, Patient Comments, Patient ID, Previus ET, Previus OD ET, Oocyte History, Oocyte Source, Oocytes Aspirated, Slide ID, Well, Embryo ID, t2, t3, t4, t5, t8, tB, tEB, tHB, tM, tPNa, tPNf, tSB, tSC, Frag-2 Cat. - Value, Fragmentation - Value, ICM - Value, MN-2 Type - Value, MN-2 Cells - Value, PN - Value, Pulsing - Value, Re-exp Count - Value, TE - Value, Embryo Description]
# Index: []

# %% [markdown]
# ### 2. Query by Patient ID

# %%
# Example: Query by Patient ID
patient_id = 515863  # Change this to your patient ID

# df_patient = query_data_ploidia(patient_id=patient_id)
# display(df_patient)

# %% [markdown]
# ### 3. Query by Embryo ID / Video ID

# %%
# Example: Query by Embryo ID
embryo_id = "E12345"  # Change this to your embryo ID

# df_embryo = query_data_ploidia(embryo_id=embryo_id)
# display(df_embryo)

# %% [markdown]
# ### 4. Query by Unidade

# %%
# Example: Query by Unidade
unidade = "BH"  # Change this to your unidade

# df_unidade = query_data_ploidia(unidade=unidade)
# display(df_unidade)

# %% [markdown]
# ### 5. Data Quality Checks

# %%
# # Check data quality - look for columns with all NULL values
# conn = get_huntington_connection()
# try:
#     print("=== COLUMNS WITH ALL NULL VALUES ===")
#     col_info = conn.execute("DESCRIBE gold.data_ploidia").df()
#     row_count = conn.execute("SELECT COUNT(*) FROM gold.data_ploidia").fetchone()[0]
    
#     all_null_cols = []
#     for col in col_info['column_name']:
#         null_count = conn.execute(f'SELECT COUNT(*) FROM gold.data_ploidia WHERE "{col}" IS NULL').fetchone()[0]
#         if null_count == row_count:
#             all_null_cols.append(col)
#             print(f"  {col} - ALL NULL")
    
#     if not all_null_cols:
#         print("  No columns are completely NULL")
#     else:
#         print(f"\nTotal columns with all NULL: {len(all_null_cols)}")
# finally:
#     conn.close()

# %% [markdown]
# ### 6. Sample Data by Column Groups

# %%
# # Display sample data grouped by column types
# conn = get_huntington_connection()
# try:
#     # Basic info columns
#     print("=== BASIC INFO COLUMNS ===")
#     basic_cols = ['Unidade', 'Video ID', 'Age', 'BMI', 'Birth Year', 'Diagnosis', 
#                   'Patient Comments', 'Patient ID', 'Well', 'Embryo ID']
#     query = f"""
#     SELECT {', '.join([f'"{col}"' for col in basic_cols])}
#     FROM gold.data_ploidia
#     LIMIT 10
#     """
#     df_basic = conn.execute(query).df()
#     display(df_basic)
    
#     print("\n=== TIME ANNOTATIONS ===")
#     time_cols = ['t2', 't3', 't4', 't5', 't8', 'tB', 'tEB', 'tHB', 'tM', 'tPNa', 'tPNf', 'tSB', 'tSC']
#     query = f"""
#     SELECT {', '.join([f'"{col}"' for col in time_cols])}
#     FROM gold.data_ploidia
#     LIMIT 10
#     """
#     df_time = conn.execute(query).df()
#     display(df_time)
    
#     print("\n=== ANNOTATION VALUES ===")
#     annot_cols = ['Frag-2 Cat. - Value', 'Fragmentation - Value', 'ICM - Value', 
#                   'MN-2 Type - Value', 'MN-2 Cells - Value', 'PN - Value', 
#                   'Pulsing - Value', 'Re-exp Count - Value', 'TE - Value', 'Embryo Description']
#     query = f"""
#     SELECT {', '.join([f'"{col}"' for col in annot_cols])}
#     FROM gold.data_ploidia
#     LIMIT 10
#     """
#     df_annot = conn.execute(query).df()
#     display(df_annot)
# finally:
#     conn.close()
