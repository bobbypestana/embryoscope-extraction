# %% [markdown]
# # Data Ploidia Query
#
# This notebook queries the `gold.data_ploidia` table to investigate the results of the column mapping and filtering.
#
# ## Table Queried:
# - **Huntington Data Lake** (huntington_data_lake.duckdb):
#   - gold.data_ploidia (mapped and filtered columns from gold.planilha_embryoscope_combined)

# %%
import duckdb
import pandas as pd
import os
from datetime import datetime

# Set pandas display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Database Connection

# %%
def get_huntington_connection():
    """Get connection to huntington_data_lake database"""
    huntington_db_path = os.path.join('..', '..', 'database', 'huntington_data_lake.duckdb')
    return duckdb.connect(huntington_db_path, read_only=True)

# %% [markdown]
# ## Query Functions

# %%
def query_data_ploidia_all(conn):
    """Query all data from gold.data_ploidia"""
    print(f"\n=== GOLD.DATA_PLOIDIA (ALL DATA) ===")
    query = """
    SELECT * FROM gold.data_ploidia
    ORDER BY "Patient ID", "Video ID"
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records in gold.data_ploidia")
    return df

def query_data_ploidia_by_patient(conn, patient_id):
    """Query gold.data_ploidia for a specific patient ID"""
    print(f"\n=== GOLD.DATA_PLOIDIA (PATIENT ID: {patient_id}) ===")
    query = f"""
    SELECT * FROM gold.data_ploidia 
    WHERE "Patient ID" = {patient_id}
    ORDER BY "Video ID"
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records for Patient ID {patient_id}")
    return df

def query_data_ploidia_by_embryo(conn, embryo_id):
    """Query gold.data_ploidia for a specific embryo ID"""
    print(f"\n=== GOLD.DATA_PLOIDIA (EMBRYO ID: {embryo_id}) ===")
    query = f"""
    SELECT * FROM gold.data_ploidia 
    WHERE "Embryo ID" = '{embryo_id}' OR "Video ID" = '{embryo_id}'
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records for Embryo ID {embryo_id}")
    return df

def query_data_ploidia_by_unidade(conn, unidade):
    """Query gold.data_ploidia for a specific unidade"""
    print(f"\n=== GOLD.DATA_PLOIDIA (UNIDADE: {unidade}) ===")
    query = f"""
    SELECT * FROM gold.data_ploidia 
    WHERE "Unidade" = '{unidade}'
    ORDER BY "Patient ID", "Video ID"
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records for Unidade {unidade}")
    return df

def get_table_info(conn):
    """Get basic statistics about the data_ploidia table"""
    print(f"\n=== TABLE INFORMATION ===")
    
    # Row count
    row_count = conn.execute("SELECT COUNT(*) FROM gold.data_ploidia").fetchone()[0]
    print(f"Total rows: {row_count:,}")
    
    # Column count and names
    col_info = conn.execute("DESCRIBE gold.data_ploidia").df()
    print(f"Total columns: {len(col_info)}")
    print(f"\nColumn names:")
    for i, col in enumerate(col_info['column_name'], 1):
        print(f"  {i:2d}. {col}")
    
    # Check for NULL values in each column
    print(f"\nNULL value counts:")
    for col in col_info['column_name']:
        null_count = conn.execute(f'SELECT COUNT(*) FROM gold.data_ploidia WHERE "{col}" IS NULL').fetchone()[0]
        null_pct = (null_count / row_count * 100) if row_count > 0 else 0
        print(f"  {col:35s}: {null_count:6,} ({null_pct:5.1f}%)")
    
    return col_info

# %% [markdown]
# ## Main Query Function

# %%
def query_data_ploidia(patient_id=None, embryo_id=None, unidade=None, show_all=False):
    """
    Query data_ploidia table with various filters.
    
    Args:
        patient_id (int, optional): Filter by Patient ID
        embryo_id (str, optional): Filter by Embryo ID or Video ID
        unidade (str, optional): Filter by Unidade
        show_all (bool): If True, return all data
        
    Returns:
        pandas.DataFrame: Query results
    """
    print(f"\n{'='*80}")
    print(f"QUERYING DATA_PLOIDIA TABLE")
    print(f"Query executed at: {datetime.now()}")
    if patient_id:
        print(f"Filter: Patient ID = {patient_id}")
    if embryo_id:
        print(f"Filter: Embryo ID = {embryo_id}")
    if unidade:
        print(f"Filter: Unidade = {unidade}")
    if show_all:
        print(f"Filter: All data")
    print(f"{'='*80}")
    
    # Connect to database
    conn = get_huntington_connection()
    
    try:
        if show_all:
            df = query_data_ploidia_all(conn)
        elif patient_id:
            df = query_data_ploidia_by_patient(conn, patient_id)
        elif embryo_id:
            df = query_data_ploidia_by_embryo(conn, embryo_id)
        elif unidade:
            df = query_data_ploidia_by_unidade(conn, unidade)
        else:
            # Default: show first 100 rows
            print(f"\n=== GOLD.DATA_PLOIDIA (FIRST 100 ROWS) ===")
            query = """
            SELECT * FROM gold.data_ploidia
            ORDER BY "Patient ID" DESC, "Age" DESC, "Well" ASC
            """
            df = conn.execute(query).df()
            print(f"Showing first 100 records")
        
        return df
        
    finally:
        # Close connection
        conn.close()
        print("\nDatabase connection closed.")

# %% [markdown]
# ## Table Information

# %%
# Get table information
conn = get_huntington_connection()
try:
    col_info = get_table_info(conn)
finally:
    conn.close()
# Out:
# === TABLE INFORMATION ===
# Total rows: 83,638
# Total columns: 49
#
# Column names:
#    1. Unidade
#    2. Video ID
#    3. Age
#    4. BMI
#    5. Birth Year
#    6. Diagnosis
#    7. Patient Comments
#    8. Patient ID
#    9. Previus ET
#   10. Previus OD ET
#   11. Oocyte History
#   12. Oocyte Source
#   13. Oocytes Aspirated
#   14. Slide ID
#   15. Well
#   16. Embryo ID
#   17. t2
#   18. t3
#   19. t4
#   20. t5
#   21. t8
#   22. tB
#   23. tEB
#   24. tHB
#   25. tM
#   26. tPNa
#   27. tPNf
#   28. tSB
#   29. tSC
#   30. Frag-2 Cat. - Value
#   31. Fragmentation - Value
#   32. ICM - Value
#   33. MN-2 Type - Value
#   34. MN-2 Cells - Value
#   35. PN - Value
#   36. Pulsing - Value
#   37. Re-exp Count - Value
#   38. TE - Value
#   39. Embryo Description
#   40. Embryo Description Clinisys
#   41. Embryo Description Clinisys Detalhes
#   42. outcome_type
#   43. merged_numero_de_nascidos
#   44. fet_gravidez_clinica
#   45. trat2_resultado_tratamento
#   46. trat1_resultado_tratamento
#   47. fet_tipo_resultado
#   48. api_response_code
#   49. api_error_message
#
# NULL value counts:
#   Unidade                            :      0 (  0.0%)
#   Video ID                           :      0 (  0.0%)
#   Age                                :    571 (  0.7%)
#   BMI                                : 25,818 ( 30.9%)
#   Birth Year                         :    571 (  0.7%)
#   Diagnosis                          : 16,008 ( 19.1%)
#   Patient Comments                   : 83,638 (100.0%)
#   Patient ID                         :      0 (  0.0%)
#   Previus ET                         :      0 (  0.0%)
#   Previus OD ET                      :      0 (  0.0%)
#   Oocyte History                     :    113 (  0.1%)
#   Oocyte Source                      :      0 (  0.0%)
#   Oocytes Aspirated                  :  5,271 (  6.3%)
#   Slide ID                           :      0 (  0.0%)
#   Well                               :      0 (  0.0%)
#   Embryo ID                          :      0 (  0.0%)
#   t2                                 : 32,467 ( 38.8%)
#   t3                                 : 35,013 ( 41.9%)
#   t4                                 : 34,889 ( 41.7%)
#   t5                                 : 36,551 ( 43.7%)
#   t8                                 : 40,107 ( 48.0%)
#   tB                                 : 48,507 ( 58.0%)
#   tEB                                : 66,217 ( 79.2%)
#   tHB                                : 74,857 ( 89.5%)
#   tM                                 : 66,553 ( 79.6%)
#   tPNa                               : 62,072 ( 74.2%)
#   tPNf                               : 31,164 ( 37.3%)
#   tSB                                : 46,443 ( 55.5%)
#   tSC                                : 66,203 ( 79.2%)
#   Frag-2 Cat. - Value                : 63,802 ( 76.3%)
#   Fragmentation - Value              : 67,129 ( 80.3%)
#   ICM - Value                        : 50,397 ( 60.3%)
#   MN-2 Type - Value                  : 63,998 ( 76.5%)
#   MN-2 Cells - Value                 : 61,883 ( 74.0%)
#   PN - Value                         : 25,293 ( 30.2%)
#   Pulsing - Value                    : 77,029 ( 92.1%)
#   Re-exp Count - Value               : 83,136 ( 99.4%)
#   TE - Value                         : 50,433 ( 60.3%)
#   Embryo Description                 : 72,675 ( 86.9%)
#   Embryo Description Clinisys        : 65,117 ( 77.9%)
#   Embryo Description Clinisys Detalhes: 68,471 ( 81.9%)
#   outcome_type                       : 73,943 ( 88.4%)
#   merged_numero_de_nascidos          : 77,824 ( 93.0%)
#   fet_gravidez_clinica               : 66,987 ( 80.1%)
#   trat2_resultado_tratamento         : 77,919 ( 93.2%)
#   trat1_resultado_tratamento         : 46,038 ( 55.0%)
#   fet_tipo_resultado                 : 53,641 ( 64.1%)
#   api_response_code                  :      0 (  0.0%)
#   api_error_message                  :      0 (  0.0%)

# %% [markdown]
# ## Example Queries
#
# ### 1. Show All Data (First 100 rows)

# %%
# Query first 100 rows
df_all = query_data_ploidia()
display(df_all.head(10))
# Out:
# ================================================================================
# QUERYING DATA_PLOIDIA TABLE
# Query executed at: 2026-02-06 09:05:11.493617
# ================================================================================
#
# === GOLD.DATA_PLOIDIA (FIRST 100 ROWS) ===
# Showing first 100 records
#
# Database connection closed.
#         Unidade                              Video ID    Age    BMI  \
# 0  Vila Mariana   906658_D2025.12.14_S03968_I3253_P-1  39.73  22.39
# 1  Vila Mariana   906658_D2025.12.14_S03968_I3253_P-2  39.73  22.39
# 2  Vila Mariana   906658_D2025.12.14_S03968_I3253_P-4  39.73  22.39
# 3  Vila Mariana   906658_D2025.12.14_S03968_I3253_P-5  39.73  22.39
# 4  Vila Mariana   906658_D2025.12.14_S03968_I3253_P-7  39.73  22.39
# 5  Vila Mariana   906658_D2025.12.14_S03968_I3253_P-8  39.73  22.39
# 6  Vila Mariana   906658_D2025.12.14_S03968_I3253_P-9  39.73  22.39
# 7  NaN NaN   NaN   NaN  NaN  NaN                None                    NaN
# 8  NaN NaN   NaN   NaN  NaN  NaN                None                    NaN
# 9  NaN NaN   NaN   NaN  NaN  NaN                None                    NaN
#
#   ICM - Value MN-2 Type - Value MN-2 Cells - Value PN - Value Pulsing - Value  \
# 0        None              None               None          2            None
# 1        None              None               None          2            None
# 2        None              None               None          2            None
# 3        None              None               None          2            None
# 4        None              None               None          2            None
# 5        None              None               None          2            None
# 6        None              None               None          2            None
# 7        None              None               None          2            None
# 8        None              None               None          2            None
# 9        None              None               None          2            None
#
#   Re-exp Count - Value TE - Value Embryo Description  \
# 0                 None       None               None
# 1                 None       None               None
# 2                 None       None               None
# 3                 None       None               None
# 4                 None       None               None
# 5                 None       None               None
# 6                 None       None               None
# 7                 None       None               None
# 8                 None       None               None
# 9                 None       None               None
#
#   Embryo Description Clinisys Embryo Description Clinisys Detalhes  \
# 0                        None                                 None
# 1                        None                                 None
# 2                        None                                 None
# 3                        None                                 None
# 4                        None                                 None
# 5                        None                                 None
# 6                        None                                 None
# 7                        None                                 None
# 8                        None                                 None
# 9                        None                                 None
#
#   outcome_type  merged_numero_de_nascidos fet_gravidez_clinica  \
# 0         None                       <NA>                 None
# 1         None                       <NA>                 None
# 2         None                       <NA>                 None
# 3         None                       <NA>                 None
# 4         None                       <NA>                 None
# 5         None                       <NA>                 None
# 6         None                       <NA>                 None
# 7         None                       <NA>                 None
# 8         None                       <NA>                 None
# 9         None                       <NA>                 None
#
#   trat2_resultado_tratamento trat1_resultado_tratamento fet_tipo_resultado  \
# 0                       None                       None               None
# 1                       None                       None               None
# 2                       None                       None               None
# 3                       None                       None               None
# 4                       None                       None               None
# 5                       None                       None               None
# 6                       None                       None               None
# 7                       None                       None               None
# 8                       None                       None               None
# 9                       None                       None               None
#
#    api_response_code api_error_message
# 0                200                OK
# 1                200                OK
# 2                200                OK
# 3                200                OK
# 4                200                OK
# 5                200                OK
# 6                200                OK
# 7                200                OK
# 8                200                OK
# 9                200                OK

# %%
patient_id = 889071
display(df_all[df_all['Patient ID']==patient_id])
# Out:
#        Unidade                              Video ID    Age    BMI  \
# 2079  Brasilia   889071_D2025.07.14_S02420_I4120_P-1  32.22  23.74
# 2080  Brasilia   889071_D2025.07.14_S02420_I4120_P-2  32.22  23.74
# 2081  Brasilia   889071_D2025.07.14_S02420_I4120_P-3  32.22  23.74
# 2082  Brasilia   889071_D2025.07.14_S02420_I4120_P-4  32.22  23.74
# 2083  Brasilia   889071_D2025.07.14_S02420_I4120_P-5  32.22  23.74
# 2084  Brasilia   889071_D2025.07.14_S02420_I4120_P-6  32.22  23.74
# 2085  Brasilia   889071_D2025.07.14_S02420_I4120_P-7  32.22  23.74
# 2086  Brasilia   889071_D2025.07.14_S02420_I4120_P-8  32.22  23.74
# 2087  Brasilia   889071_D2025.07.14_S02420_I4120_P-9  32.22  23.74
# 2088  Brasilia  889071_D2025.07.14_S02420_I4120_P-10  32.22  23.74
# 2089  Brasilia  889071_D2025.07.14_S02420_I4120_P-11  32.22  23.74
# 2089               None                        None
# 2090               None               Não analisado
# 2091               None                    Euploide
# 2092               None                  Aneuploide
# 2093               None                    Euploide
# 2094               None               Não analisado
#
#      Embryo Description Clinisys Detalhes outcome_type  \
# 2079                                 None         None
# 2080                                 None         None
# 2081                                 None         None
# 2082                                 None         None
# 2083                                 None         None
# 2084                                 None         None
# 2085                                 None         None
# 2086                   XX, Sem alterações         None
# 2087                                 None         None
# 2088                                 None         None
# 2089                                 None         None
# 2090                                 None         None
# 2091                   XY, Sem alterações         None
# 2092                 XX, Trissomia chr 17         None
# 2093                   XY, Sem alterações         None
# 2094                                 None         None
#
#       merged_numero_de_nascidos fet_gravidez_clinica  \
# 2079                       <NA>                    1
# 2080                       <NA>                    1
# 2081                       <NA>                    1
# 2082                       <NA>                    1
# 2083                       <NA>                    1
# 2084                       <NA>                    1
# 2085                       <NA>                    1
# 2086                       <NA>                    1
# 2087                       <NA>                    1
# 2088                       <NA>                    1
# 2089                       <NA>                    1
# 2090                       <NA>                    1
# 2091                       <NA>                    1
# 2092                       <NA>                    1
# 2093                       <NA>                    1
# 2094                       <NA>                    1
#
#        trat2_resultado_tratamento trat1_resultado_tratamento  \
# 2079                         None                No transfer
# 2080                         None                No transfer
# 2081                         None                No transfer
# 2082                         None                No transfer
# 2083                         None                No transfer
# 2084                         None                No transfer
# 2085                         None                No transfer
# 2086                         None                No transfer
# 2087                         None                No transfer
# 2088                         None                No transfer
# 2089                         None                No transfer
# 2090                         None                No transfer
# 2091             Gestação Clínica                No transfer
# 2092                         None                No transfer
# 2093  Gestação Química Confirmada                No transfer
# 2094                         None                No transfer
#
#      fet_tipo_resultado  api_response_code api_error_message
# 2079           POSITIVO                200                OK
# 2080           POSITIVO                200                OK
# 2081           POSITIVO                200                OK
# 2082           POSITIVO                200                OK
# 2083           POSITIVO                200                OK
# 2084           POSITIVO                200                OK
# 2085           POSITIVO                200                OK
# 2086           POSITIVO                200                OK
# 2087           POSITIVO                200                OK
# 2088           POSITIVO                200                OK
# 2089           POSITIVO                200                OK
# 2090           POSITIVO                200                OK
# 2091           POSITIVO                200                OK
# 2092           POSITIVO                200                OK
# 2093           POSITIVO                200                OK
# 2094           POSITIVO                200                OK

# %% [markdown]
# ### Análise de BH

# %%
df_all['Unidade'].value_counts(dropna=False)
# Out:
# Unidade
# Ibirapuera        29820
# Vila Mariana      23649
# Belo Horizonte    18386
# Brasilia          11783
# Name: count, dtype: int64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_bh = df_all[df_all['Unidade']=='Belo Horizonte']

df_bh.shape
# Out:
# (18386, 49)

# %%
df_bh['api_response_code'].value_counts(dropna=False)
# Out:
# api_response_code
# 204    12095
# 200     6290
# 0          1
# Name: count, dtype: int64

# %%
df_bh[df_bh['Embryo Description Clinisys'].isnull()].shape
# Out:
# (16374, 49)

# %%
df_bh[~df_bh['Embryo Description Clinisys'].isnull()].shape
# Out:
# (2012, 49)

# %%
df_bh_200 = df_bh[df_bh['api_response_code']==200]

df_bh_200.shape
# Out:
# (6290, 49)

# %%
df_bh_200[~(df_bh_200['Embryo Description'].isnull())].shape
# Out:
# (0, 49)

# %%
df_bh_200[~(df_bh_200['Embryo Description Clinisys'].isnull())].head(10)
# Out:
#             Unidade                             Video ID    Age    BMI  \
# 123  Belo Horizonte  904096_D2025.11.28_S03261_I3254_P-1  36.84  22.86
# 178  Belo Horizonte  902693_D2025.12.13_S03285_I3254_P-1  40.56  23.44
# 179  Belo Horizonte  902693_D2025.12.13_S03285_I3254_P-2  40.56  23.44
# 282  Belo Horizonte  901091_D2025.12.03_S03265_I3254_P-4  43.57  21.97
# 283  Belo Horizonte  901091_D2025.12.03_S03265_I3254_P-5  43.57  21.97
# 284  Belo Horizonte  901091_D2025.12.03_S03265_I3254_P-6  43.57  21.97
# 311  Belo Horizonte  900599_D2025.11.25_S03252_I3254_P-4  38.08  24.98
# 503  Belo Horizonte  898466_D2025.11.17_S03236_I3254_P-1  35.88  20.80
# 504  Belo Horizonte  898466_D2025.11.17_S03236_I3254_P-2  35.88  20.80
# 506  Belo Horizonte  898466_D2025.11.17_S03236_I3254_P-4  35.88  20.80
#
#      Birth Year               Diagnosis  Patient Comments  Patient ID  \
# 123        1989                    None              <NA>      904096
# 178        1985  Insuficiência ovariana              <NA>      902693
# 179        1985  Insuficiência ovariana              <NA>      902693
# 282        1982                  Outros              <NA>      901091
# 283        1982                  Outros              <NA>      901091
# 284        1982                  Outros              <NA>      901091
# 311        1987  Insuficiência ovariana              <NA>      900599
# 503        1990                  Outros              <NA>      898466
# 504        1990                  Outros              <NA>      898466
# 506        1990                  Outros              <NA>      898466
#
#      Previus ET  Previus OD ET Oocyte History Oocyte Source Oocytes Aspirated  \
# 123           0              0         Fresco      Homólogo                 3
# 178           0              0         Fresco      Homólogo                 3
# 179           0              0         Fresco      Homólogo                 3
# 282           0              0         Fresco      Homólogo                10
# 283           0              0         Fresco      Homólogo                10
# 284           0              0         Fresco      Homólogo                10
# 311           0              0         Fresco      Homólogo                 5
# 503           0              0         Fresco      Homólogo                 6
# 504           0              0         Fresco      Homólogo                 6
# 506           0              0         Fresco      Homólogo                 6
#
#                          Slide ID  Well Embryo ID    t2    t3    t4    t5  \
# 123  D2025.11.28_S03261_I3254_P-1     1       AA1  23.1  33.9  34.5  47.5
# 178  D2025.12.13_S03285_I3254_P-1     1       AA1  26.0  35.5  36.5  46.5
# 179  D2025.12.13_S03285_I3254_P-2     2       AA2  24.6  35.7  36.7  49.5
# 282  D2025.12.03_S03265_I3254_P-4     4       AA4  25.3  36.3  37.4  47.6
# 283  D2025.12.03_S03265_I3254_P-5     5       AA5  29.4  40.0  42.9  52.2
# 284  D2025.12.03_S03265_I3254_P-6     6       AA6  24.6  34.8  35.6  47.2
# 311  D2025.11.25_S03252_I3254_P-4     4       AA4  25.4  36.1  36.5  48.2
# 503  D2025.11.17_S03236_I3254_P-1     1       AC1  23.3  35.3  36.0  48.0
# 504  D2025.11.17_S03236_I3254_P-2     2       AC2  30.5  42.2  43.1  53.3
# 506  D2025.11.17_S03236_I3254_P-4     4       AC4  34.4  48.0  48.6  66.1
#
#        t8     tB    tEB  tHB     tM  tPNa  tPNf    tSB   tSC  \
# 123  54.8   99.7  108.1  NaN   88.6   8.1  21.2   90.2  78.6
# 178  64.8  101.7  109.5  NaN   86.4   5.6  23.8   91.2  65.9
# 179  66.1  111.2  115.9  NaN   94.2   6.0  22.0   99.3  73.6
# 282  58.5  102.6  106.8  NaN   87.1   5.0  23.8   95.4  78.4
# 283  57.6  102.9  108.4  NaN   92.0   6.2  27.2   96.4  75.9
# 284  52.8  107.9  117.1  NaN   87.1   6.2  22.6   93.5  66.5
# 311  52.5  108.2  121.4  NaN   85.6   6.1  23.7   89.1  74.5
# 503  52.6  111.7  112.6  NaN   98.9   4.6  21.3  106.1  71.4
# 504  62.0  124.9  130.0  NaN  112.3   7.7  28.6  118.3  94.2
# 506  80.1  120.7  131.2  NaN  104.8   7.9  33.2  107.2  88.7
#
#     Frag-2 Cat. - Value  Fragmentation - Value ICM - Value MN-2 Type - Value  \
# 123                None                   28.8           A              None
# 178                None                   31.1           A              None
# 179                None                   29.8           A              None
# 282                None                   31.7           A              None
# 283                None                   34.6           A              None
# 284                None                   29.3           A              None
# 311                None                   32.9           B              None
# 503                None                   28.9           A              None
# 504                None                   36.9           A              None
# 506                None                   41.2           A              None
#
#     MN-2 Cells - Value PN - Value Pulsing - Value Re-exp Count - Value  \
# 123               None          2            None                 None
# 178               None          2            None                 None
# 179               None          2            None                 None
# 282               None          2            None                 None
# 283               None          2            None                 None
# 284               None          2            None                 None
# 311               None          2            None                 None
# 503               None          2            None                 None
# 504               None          2            None                 None
# 506               None          2            None                 None
#
#     TE - Value Embryo Description Embryo Description Clinisys  \
# 123          A               None                    Euploide
# 178          A               None                    Euploide
# 179          A               None                    Euploide
# 282          A               None                    Euploide
# 283          A               None                  Aneuploide
# 284          A               None                  Aneuploide
# 311          C               None                  Aneuploide
# 503          A               None                    Euploide
# 504          A               None                    Euploide
# 506          B               None                  Aneuploide
#
#     Embryo Description Clinisys Detalhes outcome_type  \
# 123                                 None         None
# 178                                 None         None
# 179                                 None         None
# 282                                 None         None
# 283                                 None         None
# 284                                 None         None
# 311                                 None         None
# 503                                 None         None
# 504                                 None         None
# 506                                 None         None
#
#      merged_numero_de_nascidos fet_gravidez_clinica  \
# 123                       <NA>                 None
# 178                       <NA>                 None
# 179                       <NA>                 None
# 282                       <NA>                 None
# 283                       <NA>                 None
# 284                       <NA>                 None
# 311                       <NA>                 None
# 503                       <NA>                 None
# 504                       <NA>                 None
# 506                       <NA>                 None
#
#     trat2_resultado_tratamento trat1_resultado_tratamento fet_tipo_resultado  \
# 123                       None                No transfer               None
# 178                       None                No transfer               None
# 179                       None                No transfer               None
# 282                       None                No transfer               None
# 283                       None                No transfer               None
# 284                       None                No transfer               None
# 311                       None                No transfer               None
# 503                       None                No transfer               None
# 504                       None                No transfer               None
# 506                       None                No transfer               None
#
#      api_response_code api_error_message
# 123                200                OK
# 178                200                OK
# 179                200                OK
# 282                200                OK
# 283                200                OK
# 284                200                OK
# 311                200                OK
# 503                200                OK
# 504                200                OK
# 506                200                OK
