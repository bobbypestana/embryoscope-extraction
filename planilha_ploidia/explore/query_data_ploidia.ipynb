# %% [markdown]
# # Data Ploidia Query
#
# This notebook queries the `gold.data_ploidia` table to investigate the results of the column mapping and filtering.
#
# ## Table Queried:
# - **Huntington Data Lake** (huntington_data_lake.duckdb):
#   - gold.data_ploidia (mapped and filtered columns from gold.planilha_embryoscope_combined)

# %%
import duckdb
import pandas as pd
import os
from datetime import datetime

# Set pandas display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Database Connection

# %%
def get_huntington_connection():
    """Get connection to huntington_data_lake database"""
    huntington_db_path = os.path.join('..', '..', 'database', 'huntington_data_lake.duckdb')
    return duckdb.connect(huntington_db_path, read_only=True)

# %% [markdown]
# ## Query Functions

# %%
def query_data_ploidia_all(conn):
    """Query all data from gold.data_ploidia"""
    print(f"\n=== GOLD.DATA_PLOIDIA (ALL DATA) ===")
    query = """
    SELECT * FROM gold.data_ploidia
    ORDER BY "Patient ID", "Video ID"
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records in gold.data_ploidia")
    return df

def query_data_ploidia_by_patient(conn, patient_id):
    """Query gold.data_ploidia for a specific patient ID"""
    print(f"\n=== GOLD.DATA_PLOIDIA (PATIENT ID: {patient_id}) ===")
    query = f"""
    SELECT * FROM gold.data_ploidia 
    WHERE "Patient ID" = {patient_id}
    ORDER BY "Video ID"
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records for Patient ID {patient_id}")
    return df

def query_data_ploidia_by_embryo(conn, embryo_id):
    """Query gold.data_ploidia for a specific embryo ID"""
    print(f"\n=== GOLD.DATA_PLOIDIA (EMBRYO ID: {embryo_id}) ===")
    query = f"""
    SELECT * FROM gold.data_ploidia 
    WHERE "Embryo ID" = '{embryo_id}' OR "Video ID" = '{embryo_id}'
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records for Embryo ID {embryo_id}")
    return df

def query_data_ploidia_by_unidade(conn, unidade):
    """Query gold.data_ploidia for a specific unidade"""
    print(f"\n=== GOLD.DATA_PLOIDIA (UNIDADE: {unidade}) ===")
    query = f"""
    SELECT * FROM gold.data_ploidia 
    WHERE "Unidade" = '{unidade}'
    ORDER BY "Patient ID", "Video ID"
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records for Unidade {unidade}")
    return df

def get_table_info(conn):
    """Get basic statistics about the data_ploidia table"""
    print(f"\n=== TABLE INFORMATION ===")
    
    # Row count
    row_count = conn.execute("SELECT COUNT(*) FROM gold.data_ploidia").fetchone()[0]
    print(f"Total rows: {row_count:,}")
    
    # Column count and names
    col_info = conn.execute("DESCRIBE gold.data_ploidia").df()
    print(f"Total columns: {len(col_info)}")
    print(f"\nColumn names:")
    for i, col in enumerate(col_info['column_name'], 1):
        print(f"  {i:2d}. {col}")
    
    # Check for NULL values in each column
    print(f"\nNULL value counts:")
    for col in col_info['column_name']:
        null_count = conn.execute(f'SELECT COUNT(*) FROM gold.data_ploidia WHERE "{col}" IS NULL').fetchone()[0]
        null_pct = (null_count / row_count * 100) if row_count > 0 else 0
        print(f"  {col:35s}: {null_count:6,} ({null_pct:5.1f}%)")
    
    return col_info

# %% [markdown]
# ## Main Query Function

# %%
def query_data_ploidia(patient_id=None, embryo_id=None, unidade=None, show_all=False):
    """
    Query data_ploidia table with various filters.
    
    Args:
        patient_id (int, optional): Filter by Patient ID
        embryo_id (str, optional): Filter by Embryo ID or Video ID
        unidade (str, optional): Filter by Unidade
        show_all (bool): If True, return all data
        
    Returns:
        pandas.DataFrame: Query results
    """
    print(f"\n{'='*80}")
    print(f"QUERYING DATA_PLOIDIA TABLE")
    print(f"Query executed at: {datetime.now()}")
    if patient_id:
        print(f"Filter: Patient ID = {patient_id}")
    if embryo_id:
        print(f"Filter: Embryo ID = {embryo_id}")
    if unidade:
        print(f"Filter: Unidade = {unidade}")
    if show_all:
        print(f"Filter: All data")
    print(f"{'='*80}")
    
    # Connect to database
    conn = get_huntington_connection()
    
    try:
        if show_all:
            df = query_data_ploidia_all(conn)
        elif patient_id:
            df = query_data_ploidia_by_patient(conn, patient_id)
        elif embryo_id:
            df = query_data_ploidia_by_embryo(conn, embryo_id)
        elif unidade:
            df = query_data_ploidia_by_unidade(conn, unidade)
        else:
            # Default: show first 100 rows
            print(f"\n=== GOLD.DATA_PLOIDIA (FIRST 100 ROWS) ===")
            query = """
            SELECT * FROM gold.data_ploidia
            ORDER BY "Patient ID" DESC, "Age" DESC, "Well" ASC
            """
            df = conn.execute(query).df()
            print(f"Showing first 100 records")
        
        return df
        
    finally:
        # Close connection
        conn.close()
        print("\nDatabase connection closed.")

# %% [markdown]
# ## Table Information

# %%
# Get table information
conn = get_huntington_connection()
try:
    col_info = get_table_info(conn)
finally:
    conn.close()
# Out:
# === TABLE INFORMATION ===
# Total rows: 10,877
# Total columns: 39
#
# Column names:
#    1. Unidade
#    2. Video ID
#    3. Age
#    4. BMI
#    5. Birth Year
#    6. Diagnosis
#    7. Patient Comments
#    8. Patient ID
#    9. Previus ET
#   10. Previus OD ET
#   11. Oocyte History
#   12. Oocyte Source
#   13. Oocytes Aspirated
#   14. Slide ID
#   15. Well
#   16. Embryo ID
#   17. t2
#   18. t3
#   19. t4
#   20. t5
#   21. t8
#   22. tB
#   23. tEB
#   24. tHB
#   25. tM
#   26. tPNa
#   27. tPNf
#   28. tSB
#   29. tSC
#   30. Frag-2 Cat. - Value
#   31. Fragmentation - Value
#   32. ICM - Value
#   33. MN-2 Type - Value
#   34. MN-2 Cells - Value
#   35. PN - Value
#   36. Pulsing - Value
#   37. Re-exp Count - Value
#   38. TE - Value
#   39. Embryo Description
#
# NULL value counts:
#   Unidade                            :      0 (  0.0%)
#   Video ID                           :      0 (  0.0%)
#   Age                                :     82 (  0.8%)
#   BMI                                :  6,340 ( 58.3%)
#   Birth Year                         :     82 (  0.8%)
#   Diagnosis                          :  5,000 ( 46.0%)
#   Patient Comments                   : 10,877 (100.0%)
#   Patient ID                         :      0 (  0.0%)
#   Previus ET                         :  4,959 ( 45.6%)
#   Previus OD ET                      : 10,877 (100.0%)
#   Oocyte History                     :     16 (  0.1%)
#   Oocyte Source                      :  5,058 ( 46.5%)
#   Oocytes Aspirated                  :    530 (  4.9%)
#   Slide ID                           :      0 (  0.0%)
#   Well                               :      0 (  0.0%)
#   Embryo ID                          :      0 (  0.0%)
#   t2                                 :    254 (  2.3%)
#   t3                                 :    423 (  3.9%)
#   t4                                 :    281 (  2.6%)
#   t5                                 :    369 (  3.4%)
#   t8                                 :    390 (  3.6%)
#   tB                                 :    651 (  6.0%)
#   tEB                                :  7,813 ( 71.8%)
#   tHB                                :  8,566 ( 78.8%)
#   tM                                 :  9,329 ( 85.8%)
#   tPNa                               :  9,058 ( 83.3%)
#   tPNf                               :    250 (  2.3%)
#   tSB                                :    648 (  6.0%)
#   tSC                                :  9,322 ( 85.7%)
#   Frag-2 Cat. - Value                :  4,906 ( 45.1%)
#   Fragmentation - Value              : 10,877 (100.0%)
#   ICM - Value                        :    682 (  6.3%)
#   MN-2 Type - Value                  :  4,911 ( 45.2%)
#   MN-2 Cells - Value                 :  3,816 ( 35.1%)
#   PN - Value                         :    100 (  0.9%)
#   Pulsing - Value                    :  8,761 ( 80.5%)
#   Re-exp Count - Value               : 10,608 ( 97.5%)
#   TE - Value                         :    683 (  6.3%)
#   Embryo Description                 :      0 (  0.0%)

# %% [markdown]
# ## Example Queries
#
# ### 1. Show All Data (First 100 rows)

# %%
# Query first 100 rows
df_all = query_data_ploidia()
display(df_all.head(10))
# Out:
# ================================================================================
# QUERYING DATA_PLOIDIA TABLE
# Query executed at: 2026-01-22 10:50:20.634970
# ================================================================================
#
# === GOLD.DATA_PLOIDIA (FIRST 100 ROWS) ===
# Showing first 100 records
#
# Database connection closed.
#         Unidade                             Video ID    Age    BMI  \
# 0  Vila Mariana  904254_D2025.11.23_S03920_I3253_P-1  42.15  22.32
# 1  Vila Mariana  895789_D2025.08.29_S03735_I3253_P-2  43.07  26.35
# 2  Vila Mariana  895789_D2025.08.29_S03735_I3253_P-4  43.07  26.35
# 3  Vila Mariana  895789_D2025.08.29_S03735_I3253_P-5  43.07  26.35
# 4  Vila Mariana  895789_D2025.08.29_S03735_I3253_P-6  43.07  26.35
# 5  Vila Mariana  895368_D2025.08.23_S03724_I3253_P-1  40.83    NaN
# 6  Vila Mariana  895133_D2025.08.22_S03720_I3253_P-1  43.46  22.14
# 7  Vila Mariana  895133_D2025.08.22_S03720_I3253_P-2  43.46  22.14
# 8  Vila Mariana  895133_D2025.08.22_S03720_I3253_P-3  43.46  22.14
# 9  Vila Mariana  895133_D2025.08.22_S03720_I3253_P-4  43.46  22.14
#
#    Birth Year                 Diagnosis  Patient Comments  Patient ID  \
# 0        1983  Fator feminino anatômico              <NA>      904254
# 1        1982                      None              <NA>      895789
# 2        1982                      None              <NA>      895789
# 3        1982                      None              <NA>      895789
# 4        1982                      None              <NA>      895789
# 5        1984                      None              <NA>      895368
# 6        1982    Insuficiência ovariana              <NA>      895133
# 7        1982    Insuficiência ovariana              <NA>      895133
# 8        1982    Insuficiência ovariana              <NA>      895133
# 9        1982    Insuficiência ovariana              <NA>      895133
#
#    Previus ET  Previus OD ET   Oocyte History Oocyte Source Oocytes Aspirated  \
# 0           0           <NA>           Fresco      Homólogo                13
# 1           0           <NA>           Fresco      Homólogo                11
# 2           0           <NA>           Fresco      Homólogo                11
# 3           0           <NA>           Fresco      Homólogo                11
# 4           0           <NA>           Fresco      Homólogo                11
# 5        <NA>           <NA>           Fresco          None                 4
# 6           0           <NA>  Descongelado OR    Heterólogo                 8
# 7           0           <NA>  Descongelado OR    Heterólogo                 8
# 8           0           <NA>  Descongelado OR    Heterólogo                 8
# 9           0           <NA>  Descongelado OR    Heterólogo                 8
#
#                        Slide ID  Well Embryo ID    t2    t3    t4    t5    t8  \
# 0  D2025.11.23_S03920_I3253_P-1     1       AA1  29.4  40.8  41.0  41.2  55.6
# 1  D2025.08.29_S03735_I3253_P-2     2       AA2  22.9  33.6  41.5  44.0  60.5
# 2  D2025.08.29_S03735_I3253_P-4     4       AA4  24.0  35.6  35.7  49.2  50.8
# 3  D2025.08.29_S03735_I3253_P-5     5       AA5  24.1  37.1  38.5  53.6  58.3
# 4  D2025.08.29_S03735_I3253_P-6     6       AA6  22.6  34.0  35.6  51.8  60.5
# 5  D2025.08.23_S03724_I3253_P-1     1       AA1  29.5  40.5  41.1  57.0  59.9
# 6  D2025.08.22_S03720_I3253_P-1     1       AA1  25.4  37.4  37.8  48.7  67.5
# 7  D2025.08.22_S03720_I3253_P-2     2       AA2  29.3  42.2  43.2  55.2  59.3
# 8  D2025.08.22_S03720_I3253_P-3     3       AA3  31.2  43.8  45.1  46.6  88.2
# 9  D2025.08.22_S03720_I3253_P-4     4       AA4  26.5  38.0  38.4  51.7  52.9
#
#       tB    tEB    tHB  tM  tPNa  tPNf    tSB  tSC Frag-2 Cat. - Value  \
# 0    NaN    NaN    NaN NaN   NaN  27.1    NaN  NaN               0-10%
# 1    NaN    NaN    NaN NaN   NaN  21.0    NaN  NaN               0-10%
# 2    NaN    NaN    NaN NaN   NaN  22.0    NaN  NaN               0-10%
# 3    NaN    NaN    NaN NaN   NaN  22.2  102.0  NaN               0-10%
# 4  105.2    NaN    NaN NaN   NaN  20.7   93.8  NaN               0-10%
# 5  103.7  113.0  120.9 NaN   NaN  27.2   93.9  NaN              10-20%
# 6  112.0  116.0  118.9 NaN   NaN  22.1  105.9  NaN               0-10%
# 7  102.1  108.6    NaN NaN   NaN  26.7   95.8  NaN               0-10%
# 8  146.7  152.5  163.7 NaN   NaN  29.1  135.5  NaN               0-10%
# 9   95.6  104.4  115.5 NaN   NaN  23.3   88.6  NaN               0-10%
#
#    Fragmentation - Value ICM - Value MN-2 Type - Value MN-2 Cells - Value  \
# 0                    NaN        None             Multi                  2
# 1                    NaN        None             Multi                  2
# 2                    NaN        None             Multi                  2
# 3                    NaN        None              Mono                  2
# 4                    NaN        None              Mono                  2
# 5                    NaN           B                Bi                  1
# 6                    NaN           A              Mono                  0
# 7                    NaN           A              Mono                  0
# 8                    NaN           B                Bi                  1
# 9                    NaN           A              Mono                  0
#
#   PN - Value Pulsing - Value Re-exp Count - Value TE - Value  \
# 0          2            None                 None       None
# 1          2            None                 None       None
# 2          2            None                 None       None
# 3          2            None                 None       None
# 4          2            None                 None       None
# 5          2             Yes                 None          C
# 6          2              No                 None          A
# 7          2              No                 None          A
# 8          2             Yes                 None          B
# 9          2              No                 None          A
#
#                  Embryo Description
# 0          ANEUPLOIDE -10, +14, -18
# 1  ANEUPLOIDE +15, -18, -20, -22 XY
# 2                      SEM ANALISE
# 3                      SEM ANALISE
# 4        ANEUPLOIDE +2, +5, +16 XY
# 5                ANEUPLOIDE -19 XY
# 6                      EUPLOIDE XY
# 7                 ANEUPLOIDE -7, XY
# 8        ANORMALIDADE MULTIPLAS XXX
# 9                      EUPLOIDE XY

# %%
patient_id = 107805
display(df_all[df_all['Patient ID']==patient_id])
# Out:
#           Unidade                              Video ID    Age    BMI  \
# 10853  Ibirapuera   107805_D2025.01.19_S03985_I3166_P-1  38.41  22.86
# 10854  Ibirapuera   107805_D2025.01.19_S03985_I3166_P-4  38.41  22.86
# 10855  Ibirapuera   107805_D2025.01.19_S03985_I3166_P-6  38.41  22.86
# 10856  Ibirapuera   107805_D2025.01.19_S03985_I3166_P-7  38.41  22.86
# 10857  Ibirapuera   107805_D2025.01.19_S03985_I3166_P-9  38.41  22.86
# 10858  Ibirapuera   107805_D2024.07.27_S03829_I3027_P-2  37.93    NaN
# 10859  Ibirapuera   107805_D2024.07.27_S03829_I3027_P-5  37.93    NaN
# 10860  Ibirapuera   107805_D2024.07.27_S03829_I3027_P-6  37.93    NaN
# 10861  Ibirapuera  107805_D2024.07.27_S03829_I3027_P-10  37.93    NaN
# 10862  Ibirapuera  107805_D2024.07.27_S03829_I3027_P-11  37.93    NaN
# 10863  Ibirapuera  107805_D2024.07.27_S03829_I3027_P-13  37.93    NaN
# 10864  Ibirapuera  107805_D2024.07.27_S03829_I3027_P-15  37.93    NaN
#
#        Birth Year        Diagnosis  Patient Comments  Patient ID  Previus ET  \
# 10853        1986  Fator masculino              <NA>      107805           0
# 10854        1986  Fator masculino              <NA>      107805           0
# 10855        1986  Fator masculino              <NA>      107805           0
# 10856        1986  Fator masculino              <NA>      107805           0
# 10857        1986  Fator masculino              <NA>      107805           0
# 10858        1986             None              <NA>      107805        <NA>
# 10859        1986             None              <NA>      107805        <NA>
# 10860        1986             None              <NA>      107805        <NA>
# 10861        1986             None              <NA>      107805        <NA>
# 10862        1986             None              <NA>      107805        <NA>
# 10863        1986             None              <NA>      107805        <NA>
# 10864        1986             None              <NA>      107805        <NA>
#
#        Previus OD ET Oocyte History Oocyte Source Oocytes Aspirated  \
# 10853           <NA>         Fresco      Homólogo                10
# 10854           <NA>         Fresco      Homólogo                10
# 10855           <NA>         Fresco      Homólogo                10
# 10856           <NA>         Fresco      Homólogo                10
# 10857           <NA>         Fresco      Homólogo                10
# 10858           <NA>         Fresco          None                22
# 10859           <NA>         Fresco          None                22
# 10860           <NA>         Fresco          None                22
# 10861           <NA>         Fresco          None                22
# 10862           <NA>         Fresco          None                22
# 10863           <NA>         Fresco          None                22
# 10864           <NA>         Fresco          None                22
#
#                             Slide ID  Well Embryo ID    t2    t3    t4    t5  \
# 10853   D2025.01.19_S03985_I3166_P-1     1       AB1  21.8  32.3  32.5  33.4
# 10854   D2025.01.19_S03985_I3166_P-4     4       AB4  24.6  35.5  35.7  50.3
# 10855   D2025.01.19_S03985_I3166_P-6     6       AB6  21.8  32.1  32.5  42.9
# 10856   D2025.01.19_S03985_I3166_P-7     7       AB7  23.5  33.2  34.9  47.3
# 10857   D2025.01.19_S03985_I3166_P-9     9       AB9  25.3  36.4  51.4  51.6
# 10858   D2024.07.27_S03829_I3027_P-2     2       AA2  26.4  38.0  39.3  51.8
# 10859   D2024.07.27_S03829_I3027_P-5     5       AA5  28.5  38.9  39.7  52.0
# 10860   D2024.07.27_S03829_I3027_P-6     6       AA6  26.1  37.6  37.6  50.1
# 10861  D2024.07.27_S03829_I3027_P-10    10      AA10  25.5  37.6  40.1  41.5
# 10862  D2024.07.27_S03829_I3027_P-11    11      AA11  22.6  34.3  35.6  48.3
# 10863  D2024.07.27_S03829_I3027_P-13    13      AA13  24.2  35.4  35.6  46.7
# 10864  D2024.07.27_S03829_I3027_P-15    15      AA15  27.0  38.2  40.8  50.3
#
#          t8     tB  tEB  tHB  tM  tPNa  tPNf    tSB  tSC Frag-2 Cat. - Value  \
# 10853  52.3   99.0  NaN  NaN NaN   NaN  19.0   90.3  NaN              10-20%
# 10854  53.4  126.9  NaN  NaN NaN   NaN  21.6  109.8  NaN              10-20%
# 10855  64.4  104.7  NaN  NaN NaN   NaN  19.0   96.9  NaN               0-10%
# 10856  53.2  107.9  NaN  NaN NaN   NaN  20.6   94.7  NaN              10-20%
# 10857  69.3  102.9  NaN  NaN NaN   NaN  22.9   92.2  NaN              20-50%
# 10858  74.9  108.3  NaN  NaN NaN   NaN  24.4   96.8  NaN              10-20%
# 10859  52.8  104.4  NaN  NaN NaN   NaN  25.3   94.6  NaN               0-10%
# 10860  54.5  144.3  NaN  NaN NaN   NaN  23.3  129.8  NaN               0-10%
# 10861  84.7  123.9  NaN  NaN NaN   NaN  23.1  113.5  NaN               0-10%
# 10862  54.3  102.7  NaN  NaN NaN   NaN  20.2   93.1  NaN              20-50%
# 10863  52.2  108.8  NaN  NaN NaN   NaN  21.6   98.1  NaN               0-10%
# 10864  73.8  118.0  NaN  NaN NaN   NaN  24.8  108.6  NaN              10-20%
#
#        Fragmentation - Value ICM - Value MN-2 Type - Value MN-2 Cells - Value  \
# 10853                    NaN           A              Mono                  0
# 10854                    NaN           A              Mono                  0
# 10855                    NaN           A              Mono                  0
# 10856                    NaN           A              Mono                  0
# 10857                    NaN           B             Multi                  2
# 10858                    NaN           B                Bi                  1
# 10859                    NaN           A             Multi                  2
# 10860                    NaN           C              Mono                  0
# 10861                    NaN           C              Mono                  0
# 10862                    NaN           A              Mono                  0
# 10863                    NaN           B              Mono                  0
# 10864                    NaN           B              Mono                  0
#
#       PN - Value Pulsing - Value Re-exp Count - Value TE - Value  \
# 10853          2            None                 None          B
# 10854          2            None                 None          A
# 10855          2            None                 None          B
# 10856          2            None                 None          A
# 10857          2            None                 None          B
# 10858          2            None                 None          B
# 10859          2            None                 None          B
# 10860          2            None                 None          C
# 10861          2            None                 None          C
# 10862          2            None                 None          B
# 10863          2            None                 None          B
# 10864          2            None                 None          B
#
#                                          Embryo Description
# 10853                               Aneuploid +11q, -15, XY
# 10854                                  Euploid balanced, XY
# 10855                          Aneuploid +11q, -12, -22, XX
# 10856                           Aneuploid -13, -16,+17p, XY
# 10857                                      Aneuploid -1, XX
# 10858      Complex aneuploid /unbalanced  monossomy  21 +16
# 10859           Complex aneuploid /unbalanced monosomy  22
# 10860  Complex aneuploid /unbalanced monosomy  14,16 and 22
# 10861    Complex aneuploid /unbalanced monosomy  14,22, +21
# 10862                                    Euploid/ balanced
# 10863                            Aneuploid / unbalanced +22
# 10864                    Aneuploid / unbalanced  monossomy
