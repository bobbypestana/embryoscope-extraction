# %% [markdown]
# # Data Ploidia Query
#
# This notebook queries the `gold.data_ploidia` table to investigate the results of the column mapping and filtering.
#
# ## Table Queried:
# - **Huntington Data Lake** (huntington_data_lake.duckdb):
#   - gold.data_ploidia (mapped and filtered columns from gold.planilha_embryoscope_combined)

# %%
import duckdb
import pandas as pd
import os
from datetime import datetime

# Set pandas display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Database Connection

# %%
def get_huntington_connection():
    """Get connection to huntington_data_lake database"""
    huntington_db_path = os.path.join('..', '..', 'database', 'huntington_data_lake.duckdb')
    return duckdb.connect(huntington_db_path, read_only=True)

# %% [markdown]
# ## Query Functions

# %%
def query_data_ploidia_all(conn):
    """Query all data from gold.data_ploidia"""
    print(f"\n=== GOLD.DATA_PLOIDIA (ALL DATA) ===")
    query = """
    SELECT * FROM gold.data_ploidia
    ORDER BY "Patient ID", "Video ID"
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records in gold.data_ploidia")
    return df

def query_data_ploidia_by_patient(conn, patient_id):
    """Query gold.data_ploidia for a specific patient ID"""
    print(f"\n=== GOLD.DATA_PLOIDIA (PATIENT ID: {patient_id}) ===")
    query = f"""
    SELECT * FROM gold.data_ploidia 
    WHERE "Patient ID" = {patient_id}
    ORDER BY "Video ID"
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records for Patient ID {patient_id}")
    return df

def query_data_ploidia_by_embryo(conn, embryo_id):
    """Query gold.data_ploidia for a specific embryo ID"""
    print(f"\n=== GOLD.DATA_PLOIDIA (EMBRYO ID: {embryo_id}) ===")
    query = f"""
    SELECT * FROM gold.data_ploidia 
    WHERE "Embryo ID" = '{embryo_id}' OR "Video ID" = '{embryo_id}'
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records for Embryo ID {embryo_id}")
    return df

def query_data_ploidia_by_unidade(conn, unidade):
    """Query gold.data_ploidia for a specific unidade"""
    print(f"\n=== GOLD.DATA_PLOIDIA (UNIDADE: {unidade}) ===")
    query = f"""
    SELECT * FROM gold.data_ploidia 
    WHERE "Unidade" = '{unidade}'
    ORDER BY "Patient ID", "Video ID"
    """
    
    df = conn.execute(query).df()
    print(f"Found {len(df)} records for Unidade {unidade}")
    return df

def get_table_info(conn):
    """Get basic statistics about the data_ploidia table"""
    print(f"\n=== TABLE INFORMATION ===")
    
    # Row count
    row_count = conn.execute("SELECT COUNT(*) FROM gold.data_ploidia").fetchone()[0]
    print(f"Total rows: {row_count:,}")
    
    # Column count and names
    col_info = conn.execute("DESCRIBE gold.data_ploidia").df()
    print(f"Total columns: {len(col_info)}")
    print(f"\nColumn names:")
    for i, col in enumerate(col_info['column_name'], 1):
        print(f"  {i:2d}. {col}")
    
    # Check for NULL values in each column
    print(f"\nNULL value counts:")
    for col in col_info['column_name']:
        null_count = conn.execute(f'SELECT COUNT(*) FROM gold.data_ploidia WHERE "{col}" IS NULL').fetchone()[0]
        null_pct = (null_count / row_count * 100) if row_count > 0 else 0
        print(f"  {col:35s}: {null_count:6,} ({null_pct:5.1f}%)")
    
    return col_info

# %% [markdown]
# ## Main Query Function

# %%
def query_data_ploidia(patient_id=None, embryo_id=None, unidade=None, show_all=False):
    """
    Query data_ploidia table with various filters.
    
    Args:
        patient_id (int, optional): Filter by Patient ID
        embryo_id (str, optional): Filter by Embryo ID or Video ID
        unidade (str, optional): Filter by Unidade
        show_all (bool): If True, return all data
        
    Returns:
        pandas.DataFrame: Query results
    """
    print(f"\n{'='*80}")
    print(f"QUERYING DATA_PLOIDIA TABLE")
    print(f"Query executed at: {datetime.now()}")
    if patient_id:
        print(f"Filter: Patient ID = {patient_id}")
    if embryo_id:
        print(f"Filter: Embryo ID = {embryo_id}")
    if unidade:
        print(f"Filter: Unidade = {unidade}")
    if show_all:
        print(f"Filter: All data")
    print(f"{'='*80}")
    
    # Connect to database
    conn = get_huntington_connection()
    
    try:
        if show_all:
            df = query_data_ploidia_all(conn)
        elif patient_id:
            df = query_data_ploidia_by_patient(conn, patient_id)
        elif embryo_id:
            df = query_data_ploidia_by_embryo(conn, embryo_id)
        elif unidade:
            df = query_data_ploidia_by_unidade(conn, unidade)
        else:
            # Default: show first 100 rows
            print(f"\n=== GOLD.DATA_PLOIDIA (FIRST 100 ROWS) ===")
            query = """
            SELECT * FROM gold.data_ploidia
            ORDER BY "Patient ID" DESC, "Age" DESC, "Well" ASC
            """
            df = conn.execute(query).df()
            print(f"Showing first 100 records")
        
        return df
        
    finally:
        # Close connection
        conn.close()
        print("\nDatabase connection closed.")

# %% [markdown]
# ## Table Information

# %%
# Get table information
conn = get_huntington_connection()
try:
    col_info = get_table_info(conn)
finally:
    conn.close()
# Out:
# === TABLE INFORMATION ===
# Total rows: 10,880
# Total columns: 39
#
# Column names:
#    1. Unidade
#    2. Video ID
#    3. Age
#    4. BMI
#    5. Birth Year
#    6. Diagnosis
#    7. Patient Comments
#    8. Patient ID
#    9. Previus ET
#   10. Previus OD ET
#   11. Oocyte History
#   12. Oocyte Source
#   13. Oocytes Aspirated
#   14. Slide ID
#   15. Well
#   16. Embryo ID
#   17. t2
#   18. t3
#   19. t4
#   20. t5
#   21. t8
#   22. tB
#   23. tEB
#   24. tHB
#   25. tM
#   26. tPNa
#   27. tPNf
#   28. tSB
#   29. tSC
#   30. Frag-2 Cat. - Value
#   31. Fragmentation - Value
#   32. ICM - Value
#   33. MN-2 Type - Value
#   34. MN-2 Cells - Value
#   35. PN - Value
#   36. Pulsing - Value
#   37. Re-exp Count - Value
#   38. TE - Value
#   39. Embryo Description
#
# NULL value counts:
#   Unidade                            :      0 (  0.0%)
#   Video ID                           :      0 (  0.0%)
#   Age                                :     82 (  0.8%)
#   BMI                                :  3,977 ( 36.6%)
#   Birth Year                         :     82 (  0.8%)
#   Diagnosis                          :  2,146 ( 19.7%)
#   Patient Comments                   : 10,880 (100.0%)
#   Patient ID                         :      0 (  0.0%)
#   Previus ET                         :      0 (  0.0%)
#   Previus OD ET                      :      0 (  0.0%)
#   Oocyte History                     :     16 (  0.1%)
#   Oocyte Source                      :      0 (  0.0%)
#   Oocytes Aspirated                  :    530 (  4.9%)
#   Slide ID                           :      0 (  0.0%)
#   Well                               :      0 (  0.0%)
#   Embryo ID                          :      0 (  0.0%)
#   t2                                 :    254 (  2.3%)
#   t3                                 :    423 (  3.9%)
#   t4                                 :    281 (  2.6%)
#   t5                                 :    369 (  3.4%)
#   t8                                 :    390 (  3.6%)
#   tB                                 :    653 (  6.0%)
#   tEB                                :  7,816 ( 71.8%)
#   tHB                                :  8,569 ( 78.8%)
#   tM                                 :  9,332 ( 85.8%)
#   tPNa                               :  9,061 ( 83.3%)
#   tPNf                               :    250 (  2.3%)
#   tSB                                :    650 (  6.0%)
#   tSC                                :  9,325 ( 85.7%)
#   Frag-2 Cat. - Value                :  4,909 ( 45.1%)
#   Fragmentation - Value              : 10,880 (100.0%)
#   ICM - Value                        :    685 (  6.3%)
#   MN-2 Type - Value                  :  4,914 ( 45.2%)
#   MN-2 Cells - Value                 :  3,819 ( 35.1%)
#   PN - Value                         :    100 (  0.9%)
#   Pulsing - Value                    :  8,764 ( 80.6%)
#   Re-exp Count - Value               : 10,611 ( 97.5%)
#   TE - Value                         :    686 (  6.3%)
#   Embryo Description                 :      0 (  0.0%)

# %% [markdown]
# ## Example Queries
#
# ### 1. Show All Data (First 100 rows)

# %%
# Query first 100 rows
df_all = query_data_ploidia()
display(df_all.head(10))
# Out:
# ================================================================================
# QUERYING DATA_PLOIDIA TABLE
# Query executed at: 2026-01-13 16:40:12.656995
# ================================================================================
#
# === GOLD.DATA_PLOIDIA (FIRST 100 ROWS) ===
# Showing first 100 records
#
# Database connection closed.
#         Unidade                             Video ID    Age    BMI  \
# 0  Vila Mariana  904254_D2025.11.23_S03920_I3253_P-1  42.15  22.32
# 1  Vila Mariana  895789_D2025.08.29_S03735_I3253_P-2  43.07  26.35
# 2  Vila Mariana  895789_D2025.08.29_S03735_I3253_P-4  43.07  26.35
# 3  Vila Mariana  895789_D2025.08.29_S03735_I3253_P-5  43.07  26.35
# 4  Vila Mariana  895789_D2025.08.29_S03735_I3253_P-6  43.07  26.35
# 5  Vila Mariana  895368_D2025.08.23_S03724_I3253_P-1  40.83    NaN
# 6  Vila Mariana  895133_D2025.08.22_S03720_I3253_P-1  43.46  22.14
# 7  Vila Mariana  895133_D2025.08.22_S03720_I3253_P-2  43.46  22.14
# 8  Vila Mariana  895133_D2025.08.22_S03720_I3253_P-3  43.46  22.14
# 9  Vila Mariana  895133_D2025.08.22_S03720_I3253_P-4  43.46  22.14
#
#    Birth Year               Diagnosis  Patient Comments  Patient ID  \
# 0        1983                  Outros              <NA>      904254
# 1        1982                    None              <NA>      895789
# 2        1982                    None              <NA>      895789
# 3        1982                    None              <NA>      895789
# 4        1982                    None              <NA>      895789
# 5        1984                    None              <NA>      895368
# 6        1982  Insuficiência ovariana              <NA>      895133
# 7        1982  Insuficiência ovariana              <NA>      895133
# 8        1982  Insuficiência ovariana              <NA>      895133
# 9        1982  Insuficiência ovariana              <NA>      895133
#
#    Previus ET  Previus OD ET   Oocyte History Oocyte Source Oocytes Aspirated  \
# 0           0              0           Fresco    Autologous                13
# 1           0              0           Fresco    Autologous                11
# 2           0              0           Fresco    Autologous                11
# 3           0              0           Fresco    Autologous                11
# 4           0              0           Fresco    Autologous                11
# 5           0              0           Fresco    Autologous                 4
# 6           0              0  Descongelado OR  Heterologous                 8
# 7           0              0  Descongelado OR  Heterologous                 8
# 8           0              0  Descongelado OR  Heterologous                 8
# 9           0              0  Descongelado OR  Heterologous                 8
#
#                        Slide ID  Well Embryo ID    t2    t3    t4    t5    t8  \
# 0  D2025.11.23_S03920_I3253_P-1     1       AA1  29.4  40.8  41.0  41.2  55.6
# 1  D2025.08.29_S03735_I3253_P-2     2       AA2  22.9  33.6  41.5  44.0  60.5
# 2  D2025.08.29_S03735_I3253_P-4     4       AA4  24.0  35.6  35.7  49.2  50.8
# 3  D2025.08.29_S03735_I3253_P-5     5       AA5  24.1  37.1  38.5  53.6  58.3
# 4  D2025.08.29_S03735_I3253_P-6     6       AA6  22.6  34.0  35.6  51.8  60.5
# 5  D2025.08.23_S03724_I3253_P-1     1       AA1  29.5  40.5  41.1  57.0  59.9
# 6  D2025.08.22_S03720_I3253_P-1     1       AA1  25.4  37.4  37.8  48.7  67.5
# 7  D2025.08.22_S03720_I3253_P-2     2       AA2  29.3  42.2  43.2  55.2  59.3
# 8  D2025.08.22_S03720_I3253_P-3     3       AA3  31.2  43.8  45.1  46.6  88.2
# 9  D2025.08.22_S03720_I3253_P-4     4       AA4  26.5  38.0  38.4  51.7  52.9
#
#       tB    tEB    tHB  tM  tPNa  tPNf    tSB  tSC Frag-2 Cat. - Value  \
# 0    NaN    NaN    NaN NaN   NaN  27.1    NaN  NaN               0-10%
# 1    NaN    NaN    NaN NaN   NaN  21.0    NaN  NaN               0-10%
# 2    NaN    NaN    NaN NaN   NaN  22.0    NaN  NaN               0-10%
# 3    NaN    NaN    NaN NaN   NaN  22.2  102.0  NaN               0-10%
# 4  105.2    NaN    NaN NaN   NaN  20.7   93.8  NaN               0-10%
# 5  103.7  113.0  120.9 NaN   NaN  27.2   93.9  NaN              10-20%
# 6  112.0  116.0  118.9 NaN   NaN  22.1  105.9  NaN               0-10%
# 7  102.1  108.6    NaN NaN   NaN  26.7   95.8  NaN               0-10%
# 8  146.7  152.5  163.7 NaN   NaN  29.1  135.5  NaN               0-10%
# 9   95.6  104.4  115.5 NaN   NaN  23.3   88.6  NaN               0-10%
#
#    Fragmentation - Value ICM - Value MN-2 Type - Value MN-2 Cells - Value  \
# 0                    NaN        None             Multi                  2
# 1                    NaN        None             Multi                  2
# 2                    NaN        None             Multi                  2
# 3                    NaN        None              Mono                  2
# 4                    NaN        None              Mono                  2
# 5                    NaN           B                Bi                  1
# 6                    NaN           A              Mono                  0
# 7                    NaN           A              Mono                  0
# 8                    NaN           B                Bi                  1
# 9                    NaN           A              Mono                  0
#
#   PN - Value Pulsing - Value Re-exp Count - Value TE - Value  \
# 0          2            None                 None       None
# 1          2            None                 None       None
# 2          2            None                 None       None
# 3          2            None                 None       None
# 4          2            None                 None       None
# 5          2             Yes                 None          C
# 6          2              No                 None          A
# 7          2              No                 None          A
# 8          2             Yes                 None          B
# 9          2              No                 None          A
#
#                  Embryo Description
# 0          ANEUPLOIDE -10, +14, -18
# 1  ANEUPLOIDE +15, -18, -20, -22 XY
# 2                      SEM ANALISE
# 3                      SEM ANALISE
# 4        ANEUPLOIDE +2, +5, +16 XY
# 5                ANEUPLOIDE -19 XY
# 6                      EUPLOIDE XY
# 7                 ANEUPLOIDE -7, XY
# 8        ANORMALIDADE MULTIPLAS XXX
# 9                      EUPLOIDE XY

# %%
patient_id = 792575
display(df_all[df_all['Patient ID']==patient_id])
# Out:
#          Unidade                             Video ID    Age   BMI  \
# 4105  Ibirapuera  792575_D2024.06.19_S03601_I3166_P-1  40.01  28.4
# 4106  Ibirapuera  792575_D2024.06.19_S03601_I3166_P-2  40.01  28.4
# 4107  Ibirapuera  792575_D2024.06.19_S03601_I3166_P-3  40.01  28.4
# 4108  Ibirapuera  792575_D2024.06.19_S03601_I3166_P-4  40.01  28.4
# 4109  Ibirapuera  792575_D2024.06.19_S03601_I3166_P-5  40.01  28.4
# 4110  Ibirapuera  792575_D2024.06.19_S03601_I3166_P-7  40.01  28.4
# 4111  Ibirapuera  792575_D2024.06.19_S03601_I3166_P-9  40.01  28.4
#
#       Birth Year        Diagnosis  Patient Comments  Patient ID  Previus ET  \
# 4105        1984  Fator masculino              <NA>      792575           1
# 4106        1984  Fator masculino              <NA>      792575           1
# 4107        1984  Fator masculino              <NA>      792575           1
# 4108        1984  Fator masculino              <NA>      792575           1
# 4109        1984  Fator masculino              <NA>      792575           1
# 4110        1984  Fator masculino              <NA>      792575           1
# 4111        1984  Fator masculino              <NA>      792575           1
#
#       Previus OD ET Oocyte History Oocyte Source Oocytes Aspirated  \
# 4105              0         Fresco    Autologous                12
# 4106              0         Fresco    Autologous                12
# 4107              0         Fresco    Autologous                12
# 4108              0         Fresco    Autologous                12
# 4109              0         Fresco    Autologous                12
# 4110              0         Fresco    Autologous                12
# 4111              0         Fresco    Autologous                12
#
#                           Slide ID  Well Embryo ID    t2    t3    t4    t5  \
# 4105  D2024.06.19_S03601_I3166_P-1     1       AA1  21.8  32.0  32.3  44.7
# 4106  D2024.06.19_S03601_I3166_P-2     2       AA2  22.5  36.3  58.1  60.5
# 4107  D2024.06.19_S03601_I3166_P-3     3       AA3  25.9  37.9  38.2  49.0
# 4108  D2024.06.19_S03601_I3166_P-4     4       AA4  24.1  35.4  38.8  47.1
# 4109  D2024.06.19_S03601_I3166_P-5     5       AA5  23.6  34.3  34.5  44.8
# 4110  D2024.06.19_S03601_I3166_P-7     7       AA7  23.9  35.4  35.6  49.7
# 4111  D2024.06.19_S03601_I3166_P-9     9       AA9  32.1  44.0  44.7  61.7
#
#         t8     tB  tEB  tHB  tM  tPNa  tPNf    tSB  tSC Frag-2 Cat. - Value  \
# 4105  45.7   89.4  NaN  NaN NaN   NaN  19.5   84.7  NaN              10-20%
# 4106  88.0  103.3  NaN  NaN NaN   NaN  20.2   90.8  NaN              10-20%
# 4107  50.8  103.0  NaN  NaN NaN   NaN  23.7   98.6  NaN              10-20%
# 4108  72.9  104.9  NaN  NaN NaN   NaN  21.3   91.5  NaN              20-50%
# 4109  49.3  110.6  NaN  NaN NaN   NaN  20.8   98.8  NaN              10-20%
# 4110  57.7  105.1  NaN  NaN NaN   NaN  21.3   98.5  NaN              20-50%
# 4111  65.3  112.4  NaN  NaN NaN   NaN  30.0  101.8  NaN              20-50%
#
#       Fragmentation - Value ICM - Value MN-2 Type - Value MN-2 Cells - Value  \
# 4105                    NaN           A             Multi                  1
# 4106                    NaN           B             Multi                  1
# 4107                    NaN           A              Mono                  0
# 4108                    NaN           B              Mono                  0
# 4109                    NaN           B                Bi                  2
# 4110                    NaN           B              Mono                  0
# 4111                    NaN           A              Mono                  0
#
#      PN - Value Pulsing - Value Re-exp Count - Value TE - Value  \
# 4105          2            None                 None          A
# 4106          3            None                 None          B
# 4107          2            None                 None          A
# 4108          3            None                 None          C
# 4109          2            None                 None          B
# 4110          2            None                 None          B
# 4111          2            None                 None          A
#
#                         Embryo Description
# 4105  Complex aneuploid -10q, +13, +22, XY
# 4106                           sem analise
# 4107                           Euploid, XY
# 4108                           sem analise
# 4109        Complex aneuploid +15, -18, XY
# 4110                           Euploid, XX
# 4111                     Aneuploid -13, XX
